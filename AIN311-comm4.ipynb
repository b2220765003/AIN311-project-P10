# %% [markdown]
# After detailed research, we decided to fetch the data to be utilized within the scope of the model to be developed from the BoxScoreAdvancedV2 API. In order to validate the model, we planned to make transfer predictions for the past seasons as well. For this reason, we fetch 10 years of records from the 2015-16 season to 2024-25. Specified data consists of detailed player statistics for an individual game. The advanced attributes can be listed as follows:
#
# * START_POSITION: The starting position of the player in the game (e.g., "G" for Guard, "C" for Center).
# * MIN: Total minutes played by the player during the game.
# * OFF_RATING (Offensive Rating): Points scored per 100 possessions by the team while the player was on the court.
# * DEF_RATING (Defensive Rating): Points allowed per 100 possessions by the team while the player was on the court.
# * AST_PCT (Assist Percentage): The percentage of teammate field goals that the player assisted while on the court.
# * AST_TOV (Assist to Turnover Ratio): Ratio of assists to turnovers made by the player.
# * AST_RATIO (Assist Ratio): Assists per 100 possessions used by the player.
# * OREB_PCT (Offensive Rebound Percentage): Percentage of available offensive rebounds a player grabbed while on the court.
# * DREB_PCT (Defensive Rebound Percentage): Percentage of available defensive rebounds a player grabbed while on the court.
# * REB_PCT (Rebound Percentage): Percentage of total rebounds (offensive + defensive) a player grabbed while on the court.
# * TM_TOV_PCT (Team Turnover Percentage): The percentage of team possessions ending in a turnover while the player was on the court.
# * EFG_PCT (Effective Field Goal Percentage): A shooting percentage adjusted to account for the fact that three-point shots are worth more than two-point shots.
# * TS_PCT (True Shooting Percentage): A shooting efficiency metric that accounts for field goals, three-pointers, and free throws.
# * USG_PCT (Usage Percentage): The percentage of team plays used by the player while on the court (includes field goal attempts, free throw attempts, and turnovers).
# * PACE: The number of possessions per 48 minutes by the player's team while they were on the court.
# * PACE_PER40: Adjusted pace statistic per 40 minutes instead of 48.
# * POSS: Total number of possessions the player was involved in during the game.
# * PIE (Player Impact Estimate): A metric that estimates a player's overall statistical contribution to the game relative to the total statistics of the game.

# %% [markdown]
# After the return from the API, we push the data directly to a csv file.

# %%
import pandas as pd
import seaborn as sns
import pandas as pd
df = pd.read_csv("PlayerStats_2015-2025.csv")
df.head()
# Out:
#     GAME_ID   GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407  2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407  2016-06-19  1610612739               CLE  Cleveland       2544
# 2  41500407  2016-06-19  1610612739               CLE  Cleveland     201567
# 3  41500407  2016-06-19  1610612739               CLE  Cleveland     201567
# 4  41500407  2016-06-19  1610612739               CLE  Cleveland     202684
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT  ... TM_TOV_PCT  EFG_PCT  \
# 0      LeBron James   LeBron              F     NaN  ...       11.4    0.396
# 1      LeBron James   LeBron              F     NaN  ...       11.4    0.396
# 2        Kevin Love    Kevin              F     NaN  ...        6.7    0.333
# 3        Kevin Love    Kevin              F     NaN  ...        6.7    0.333
# 4  Tristan Thompson  Tristan              C     NaN  ...        0.0    1.000
#
#    TS_PCT  USG_PCT  E_USG_PCT  E_PACE   PACE  PACE_PER40  POSS    PIE
# 0   0.475    0.330      0.329   93.33  89.71       74.75    87  0.190
# 1   0.475    0.330      0.329   93.33  89.71       74.75    87  0.190
# 2   0.418    0.179      0.178   92.51  87.10       72.59    55  0.180
# 3   0.418    0.179      0.178   92.51  87.10       72.59    55  0.180
# 4   0.945    0.074      0.075   93.92  92.05       76.71    61  0.073
#
# [5 rows x 33 columns]

# %%
df.drop(
    columns=[
        "COMMENT",
        "E_OFF_RATING",
        "E_DEF_RATING",
        "E_NET_RATING",
        "E_USG_PCT",
        "NET_RATING",
        "E_PACE"
    ],
    inplace=True,
)

# %%
df.dropna(subset=["MIN"], inplace=True)

# %%
def get_sec(time_str):
    minute, s = time_str.split(":")
    m = minute.split(".")
    return int(m[0]) * 60 + int(s)

# %%
df.loc[:, "MIN"] = df.loc[:, "MIN"].map(lambda x: get_sec(x))

# %%
df
# Out:
#          GAME_ID   GAME_DATE     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  \
# 0       41500407  2016-06-19  1610612739               CLE    Cleveland
# 1       41500407  2016-06-19  1610612739               CLE    Cleveland
# 2       41500407  2016-06-19  1610612739               CLE    Cleveland
# 3       41500407  2016-06-19  1610612739               CLE    Cleveland
# 4       41500407  2016-06-19  1610612739               CLE    Cleveland
# ...          ...         ...         ...               ...          ...
# 661528  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 661529  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 661530  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 661531  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 661532  12400003  2024-10-04  1610612747               LAL  Los Angeles
#
#         PLAYER_ID       PLAYER_NAME NICKNAME START_POSITION   MIN  ...  \
# 0            2544      LeBron James   LeBron              F  2809  ...
# 1            2544      LeBron James   LeBron              F  2809  ...
# 2          201567        Kevin Love    Kevin              F  1802  ...
# 3          201567        Kevin Love    Kevin              F  1802  ...
# 4          202684  Tristan Thompson  Tristan              C  1909  ...
# ...           ...               ...      ...            ...   ...  ...
# 661528    1642422      Armel Traore    Armel            NaN   250  ...
# 661529    1630283      Kylor Kelley    Kylor            NaN   354  ...
# 661530    1630283      Kylor Kelley    Kylor            NaN   354  ...
# 661531    1642439    Quincy Olivari   Quincy            NaN   185  ...
# 661532    1642439    Quincy Olivari   Quincy            NaN   185  ...
#
#         DREB_PCT  REB_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT    PACE  \
# 0          0.192    0.109        11.4    0.396   0.475    0.330   89.71
# 1          0.192    0.109        11.4    0.396   0.475    0.330   89.71
# 2          0.294    0.215         6.7    0.333   0.418    0.179   87.10
# 3          0.294    0.215         6.7    0.333   0.418    0.179   87.10
# 4          0.083    0.043         0.0    1.000   0.945    0.074   92.05
# ...          ...      ...         ...      ...     ...      ...     ...
# 661528     0.000    0.111         0.0    1.000   1.025    0.182  109.44
# 661529     0.000    0.000        20.0    0.667   0.667    0.364   89.49
# 661530     0.000    0.000        20.0    0.667   0.667    0.364   89.49
# 661531     0.667    0.333        50.0    0.000   1.136    0.250  108.97
# 661532     0.667    0.333        50.0    0.000   1.136    0.250  108.97
#
#         PACE_PER40  POSS    PIE
# 0            74.75    87  0.190
# 1            74.75    87  0.190
# 2            72.59    55  0.180
# 3            72.59    55  0.180
# 4            76.71    61  0.073
# ...            ...   ...    ...
# 661528       91.20    10  0.243
# 661529       74.58    11  0.037
# 661530       74.58    11  0.037
# 661531       90.81     7  0.381
# 661532       90.81     7  0.381
#
# [541984 rows x 26 columns]

# %%
df.START_POSITION.value_counts(dropna=False)
# Out:
# START_POSITION
# NaN    291502
# F      100192
# G      100192
# C       50098
# Name: count, dtype: int64

# %%
import numpy as np
mapping = {
    np.nan: 0,
    "G": 1,
    "F": 2, 
    "C": 3
    }
    
df.loc[:, "START_POSITION"] = df.START_POSITION.map(mapping)
df.loc[:, "START_POSITION"] = df.loc[:, "START_POSITION"].astype(int)

# %%
df.isnull().sum()
# Out:
# GAME_ID              0
# GAME_DATE            0
# TEAM_ID              0
# TEAM_ABBREVIATION    0
# TEAM_CITY            0
# PLAYER_ID            0
# PLAYER_NAME          0
# NICKNAME             0
# START_POSITION       0
# MIN                  0
# OFF_RATING           0
# DEF_RATING           0
# AST_PCT              0
# AST_TOV              0
# AST_RATIO            0
# OREB_PCT             0
# DREB_PCT             0
# REB_PCT              0
# TM_TOV_PCT           0
# EFG_PCT              0
# TS_PCT               0
# USG_PCT              0
# PACE                 0
# PACE_PER40           0
# POSS                 0
# PIE                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 271020

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.columns
# Out:
# Index(['GAME_ID', 'GAME_DATE', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY',
#        'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'MIN',
#        'OFF_RATING', 'DEF_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO',
#        'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT',
#        'USG_PCT', 'PACE', 'PACE_PER40', 'POSS', 'PIE'],
#       dtype='object')

# %%
df
# Out:
#          GAME_ID   GAME_DATE     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  \
# 0       41500407  2016-06-19  1610612739               CLE    Cleveland
# 1       41500407  2016-06-19  1610612739               CLE    Cleveland
# 2       41500407  2016-06-19  1610612739               CLE    Cleveland
# 3       41500407  2016-06-19  1610612739               CLE    Cleveland
# 4       41500407  2016-06-19  1610612739               CLE    Cleveland
# ...          ...         ...         ...               ...          ...
# 270959  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 270960  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 270961  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 270962  12400003  2024-10-04  1610612747               LAL  Los Angeles
# 270963  12400003  2024-10-04  1610612747               LAL  Los Angeles
#
#         PLAYER_ID       PLAYER_NAME NICKNAME START_POSITION   MIN  ...  \
# 0            2544      LeBron James   LeBron              2  2809  ...
# 1          201567        Kevin Love    Kevin              2  1802  ...
# 2          202684  Tristan Thompson  Tristan              3  1909  ...
# 3            2747          JR Smith       JR              1  2335  ...
# 4          202681      Kyrie Irving    Kyrie              1  2580  ...
# ...           ...               ...      ...            ...   ...  ...
# 270959    1642355      Bronny James   Bronny              0   964  ...
# 270960    1630658   Colin Castleton    Colin              0   711  ...
# 270961    1642422      Armel Traore    Armel              0   250  ...
# 270962    1630283      Kylor Kelley    Kylor              0   354  ...
# 270963    1642439    Quincy Olivari   Quincy              0   185  ...
#
#         DREB_PCT  REB_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT    PACE  \
# 0          0.192    0.109        11.4    0.396   0.475    0.330   89.71
# 1          0.294    0.215         6.7    0.333   0.418    0.179   87.10
# 2          0.083    0.043         0.0    1.000   0.945    0.074   92.05
# 3          0.093    0.047        11.8    0.462   0.462    0.176   90.66
# 4          0.064    0.065         7.4    0.478   0.525    0.277   89.30
# ...          ...      ...         ...      ...     ...      ...     ...
# 270959     0.053    0.029        12.5    0.167   0.167    0.200  100.08
# 270960     0.067    0.083        20.0    0.000   0.568    0.094  121.52
# 270961     0.000    0.111         0.0    1.000   1.025    0.182  109.44
# 270962     0.000    0.000        20.0    0.667   0.667    0.364   89.49
# 270963     0.667    0.333        50.0    0.000   1.136    0.250  108.97
#
#         PACE_PER40  POSS    PIE
# 0            74.75    87  0.190
# 1            72.59    55  0.180
# 2            76.71    61  0.073
# 3            75.55    73  0.043
# 4            74.42    80  0.109
# ...            ...   ...    ...
# 270959       83.40    33 -0.007
# 270960      101.27    30  0.022
# 270961       91.20    10  0.243
# 270962       74.58    11  0.037
# 270963       90.81     7  0.381
#
# [270964 rows x 26 columns]

# %%
features = [
    col
    for col in df.columns
    if col
    not in (
        "GAME_ID",
        "TEAM_ID",
        "TEAM_ABBREVIATION",
        "TEAM_CITY",
        "PLAYER_ID",
        "PLAYER_NAME",
        "NICKNAME",
        "GAME_DATE"
    )
]

# %%
import matplotlib.pyplot as plt
import math

num_features = len(features)
num_cols = 3 
num_rows = math.ceil(num_features / num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()

for i, feature in enumerate(features):
    axes[i].hist(df[feature].dropna(), bins=30, alpha=0.7, color='blue', edgecolor='black')
    axes[i].set_title(f"{feature}")
    axes[i].set_ylabel("Frequency")
    axes[i].grid(axis='y', alpha=0.75)

for i in range(len(features), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the plots, we can say most of the variables are right skewed while MIN, OFF_RATING and POSS introduce a slightly more normal distribution.

# %%
df[features].describe()
# Out:
#           OFF_RATING     DEF_RATING        AST_PCT        AST_TOV  \
# count  270964.000000  270964.000000  270964.000000  270964.000000
# mean      105.572386     107.968846       0.138960       1.019675
# std        24.747420      24.554691       0.144605       1.582894
# min         0.000000       0.000000       0.000000       0.000000
# 25%        94.100000      95.700000       0.000000       0.000000
# 50%       107.300000     108.200000       0.107000       0.330000
# 75%       120.000000     120.800000       0.211000       1.500000
# max       350.000000     500.000000       1.000000      20.000000
#
#            AST_RATIO       OREB_PCT       DREB_PCT        REB_PCT  \
# count  270964.000000  270964.000000  270964.000000  270964.000000
# mean       16.246016       0.041238       0.135281       0.088425
# std        15.778483       0.063211       0.112341       0.070405
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.059000       0.041000
# 50%        14.300000       0.000000       0.118000       0.077000
# 75%        25.000000       0.063000       0.190000       0.123000
# max       100.000000       1.000000       1.000000       1.000000
#
#          TM_TOV_PCT        EFG_PCT         TS_PCT        USG_PCT  \
# count  270964.00000  270964.000000  270964.000000  270964.000000
# mean       10.23082       0.487696       0.520194       0.183698
# std        12.79162       0.290735       0.279419       0.086516
# min         0.00000       0.000000       0.000000       0.000000
# 25%         0.00000       0.333000       0.372000       0.128000
# 50%         7.70000       0.500000       0.533000       0.179000
# 75%        15.40000       0.667000       0.688000       0.236000
# max       100.00000       1.500000       1.500000       1.000000
#
#                 PACE     PACE_PER40           POSS            PIE
# count  270964.000000  270964.000000  270964.000000  270964.000000
# mean      102.784491      85.653714      46.574918       0.088382
# std        95.225405      79.354499      21.962739       0.175380
# min         0.000000       0.000000       0.000000     -14.000000
# 25%        96.000000      80.000000      31.000000       0.035000
# 50%       100.430000      83.690000      48.000000       0.089000
# 75%       105.220000      87.680000      64.000000       0.143000
# max     28811.520000   24009.600000     121.000000      15.000000

# %%
num_fts = features.copy()
num_fts.remove('START_POSITION')

# %%
corrs = df[num_fts].corr()

plt.figure(figsize=(16, 9))
sns.heatmap(corrs, cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# ## Grouping

# %%
# shooting guard
sg_group_1 = ['OFF_RATING', 'AST_PCT', 'AST_TOV', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'POSS']
sg_group_2 = ['MIN', 'AST_RATIO', 'DREB_PCT']
sg_group_3 = ['OREB_PCT', 'REB_PCT', 'USG_PCT', 'PACE', 'PACE_PER40', 'PIE']
sg_group_4 = ['START_POSITION']
sg_group_5 = ['DEF_RATING']

# point guard
pg_group_1 = ['OFF_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO', 'EFG_PCT', 'TS_PCT', 'POSS']
pg_group_2 = ['MIN', 'USG_PCT', 'DREB_PCT']
pg_group_3 = ['OREB_PCT', 'REB_PCT', 'PIE']
pg_group_4 = ['START_POSITION']
pg_group_5 = ['DEF_RATING']

# small forward
sf_group_1 = ['OFF_RATING', 'AST_PCT', 'EFG_PCT', 'TS_PCT', 'POSS']
sf_group_2 = ['MIN', 'AST_RATIO', 'USG_PCT']
sf_group_3 = ['OREB_PCT', 'REB_PCT', 'PIE']
sf_group_4 = ['START_POSITION']
sf_group_5 = ['DEF_RATING']

# power forward
pf_group_1 = ['OFF_RATING', 'EFG_PCT', 'TS_PCT', 'POSS', 'USG_PCT']
pf_group_2 = ['MIN', 'AST_RATIO', 'DREB_PCT']
pf_group_3 = ['OREB_PCT', 'REB_PCT', 'PIE']
pf_group_4 = ['START_POSITION']
pf_group_5 = ['DEF_RATING']

# center
c_group_1 = ['DEF_RATING', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'POSS']
c_group_2 = ['MIN', 'USG_PCT', 'DREB_PCT']
c_group_3 = ['OFF_RATING', 'EFG_PCT', 'TS_PCT', 'PIE']
c_group_4 = ['START_POSITION']
c_group_5 = ['AST_PCT']

# %%
df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])

df_2015_2021 = df[(df['GAME_DATE'].dt.year >= 2015) & (df['GAME_DATE'].dt.year <= 2021)]

df_2022_2024 = df[(df['GAME_DATE'].dt.year >= 2022) & (df['GAME_DATE'].dt.year <= 2024)]

print(f"2015-2021: {df_2015_2021.shape}, 2022-2024: {df_2022_2024.shape}")
# Out:
# 2015-2021: (187805, 26), 2022-2024: (83159, 26)

# %%
df_2015_2021.to_csv('nba_data_2015_2021.csv', index=False)
df_2022_2024.to_csv('nba_data_2022_2024.csv', index=False)

# %% [markdown]
# ## PCA

# %%
data_2015_2021 = df_2015_2021[features].copy()

# %%
data_scaled = data_2015_2021.copy()
data_scaled.head()
# Out:
#   START_POSITION   MIN  OFF_RATING  DEF_RATING  AST_PCT  AST_TOV  AST_RATIO  \
# 0              2  2809       103.4        97.7    0.458      2.2       25.0
# 1              2  1802       120.0        87.0    0.150      3.0       20.0
# 2              3  1909       100.0        96.7    0.000      0.0        0.0
# 3              1  2335       113.7       102.7    0.087      1.0       11.8
# 4              1  2580       108.8        96.3    0.050      0.5        3.7
#
#    OREB_PCT  DREB_PCT  REB_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT   PACE  \
# 0     0.020     0.192    0.109        11.4    0.396   0.475    0.330  89.71
# 1     0.129     0.294    0.215         6.7    0.333   0.418    0.179  87.10
# 2     0.000     0.083    0.043         0.0    1.000   0.945    0.074  92.05
# 3     0.000     0.093    0.047        11.8    0.462   0.462    0.176  90.66
# 4     0.065     0.064    0.065         7.4    0.478   0.525    0.277  89.30
#
#    PACE_PER40  POSS    PIE
# 0       74.75    87  0.190
# 1       72.59    55  0.180
# 2       76.71    61  0.073
# 3       75.55    73  0.043
# 4       74.42    80  0.109

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_scaled)

# %%
data_scaled
# Out:
# array([[0.66666667, 0.72062596, 0.29542857, ..., 0.00622668, 0.71900826,
#         0.61695652],
#        [0.66666667, 0.46228835, 0.34285714, ..., 0.00604675, 0.45454545,
#         0.61652174],
#        [1.        , 0.48973833, 0.28571429, ..., 0.00638994, 0.50413223,
#         0.61186957],
#        ...,
#        [0.        , 0.19061057, 0.20114286, ..., 0.00739871, 0.2231405 ,
#         0.60869565],
#        [0.        , 0.14930734, 0.22857143, ..., 0.00686975, 0.16528926,
#         0.60804348],
#        [0.        , 0.11159569, 0.26657143, ..., 0.00689391, 0.12396694,
#         0.61695652]])

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(data_scaled)
pca.explained_variance_ratio_
# Out:
# array([4.18330605e-01, 1.93054526e-01, 1.30927388e-01, 8.37427377e-02,
#        4.89088398e-02, 4.35878316e-02, 2.71162327e-02, 1.29252775e-02,
#        1.05580295e-02, 1.01365059e-02, 6.73608292e-03, 6.57815029e-03,
#        5.49537823e-03, 9.13668973e-04, 6.76145187e-04, 1.93478540e-04,
#        1.19122917e-04, 1.41122226e-13])

# %%
with plt.style.context('ggplot'):
    fig = plt.figure(figsize=(10, 8))
    plt.plot(range(1, 19), pca.explained_variance_ratio_.cumsum(), 
             markerfacecolor='blue', marker='s', linestyle='-', linewidth=2)
    plt.xlabel('Principal Components', fontsize=18)
    plt.ylabel('Explained Variance %', fontsize=18)
    plt.xticks(ticks=range(1, 19), fontsize=16)
    plt.yticks(fontsize=16)
    plt.title('Cumulative Explained Variance by PCA', fontsize=20)
    plt.show()

# %%
pca = PCA(n_components = 4)
pca.fit(data_scaled)
pca_scores = pca.transform(data_scaled)

# %% [markdown]
# ## K-Means

# %%
km_df = df_2015_2021.copy()

# %%
from sklearn.cluster import KMeans
wcss = list()

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='random', random_state=1)
    kmeans.fit(pca_scores)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [54215.61804231871,
#  32261.542777814495,
#  25262.138444226934,
#  20445.824390534486,
#  18178.128989783305,
#  16115.903340616409,
#  14671.356935084828,
#  13599.132021093168,
#  12662.579428719793,
#  11881.957945923647]

# %%
from kneed import KneeLocator

with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(10, 8))
    plt.plot(range(1, 11), wcss, marker='o', markerfacecolor='red', linestyle='--')
    plt.vlines(KneeLocator([i for i in range(1, 11)], wcss, curve='convex', direction='decreasing').knee, ymin=min(
        wcss), ymax=max(wcss), linestyles='dotted', color='orange')
    plt.xlabel('Number of Clusters', fontsize=18)
    plt.ylabel('Within Cluster Sum of Squares (WCSS)', fontsize=18)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.show()

n_clusters = KneeLocator([i for i in range(1, 11)], wcss, curve='convex', direction='decreasing').knee
print("Optimal number of clusters:", n_clusters)
# Out:
# Optimal number of clusters: 4

# %%
kmeans_pca = KMeans(n_clusters=4, init='random', random_state=1)
kmeans_pca.fit_predict(pca_scores)
km_df['km_cluster'] = kmeans_pca.labels_

# %%
pca_km_df = pd.concat([km_df.reset_index(drop=True), pd.DataFrame(
    data=pca_scores, columns=['pca_1', 'pca_2', 'pca_3', 'pca_4'])], axis=1)

# %%
pca_km_df.head()
# Out:
#     GAME_ID  GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407 2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407 2016-06-19  1610612739               CLE  Cleveland     201567
# 2  41500407 2016-06-19  1610612739               CLE  Cleveland     202684
# 3  41500407 2016-06-19  1610612739               CLE  Cleveland       2747
# 4  41500407 2016-06-19  1610612739               CLE  Cleveland     202681
#
#         PLAYER_NAME NICKNAME START_POSITION   MIN  ...  USG_PCT   PACE  \
# 0      LeBron James   LeBron              2  2809  ...    0.330  89.71
# 1        Kevin Love    Kevin              2  1802  ...    0.179  87.10
# 2  Tristan Thompson  Tristan              3  1909  ...    0.074  92.05
# 3          JR Smith       JR              1  2335  ...    0.176  90.66
# 4      Kyrie Irving    Kyrie              1  2580  ...    0.277  89.30
#
#    PACE_PER40  POSS    PIE  km_cluster     pca_1     pca_2     pca_3     pca_4
# 0       74.75    87  0.190           1  0.572885 -0.080019  0.390113  0.114654
# 1       72.59    55  0.180           1  0.385601 -0.214780  0.036019 -0.063064
# 2       76.71    61  0.073           1  0.784950  0.161279 -0.342901 -0.064941
# 3       75.55    73  0.043           3  0.188411 -0.000870  0.095659  0.276210
# 4       74.42    80  0.109           3  0.237746  0.044494  0.051963  0.384982
#
# [5 rows x 31 columns]

# %%
pca_km_df.km_cluster.value_counts()
# Out:
# km_cluster
# 2    55651
# 1    51770
# 3    42038
# 0    38346
# Name: count, dtype: int64

# %%
pca_km_df.groupby(['km_cluster'])[sg_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   AST_TOV  TM_TOV_PCT   EFG_PCT    TS_PCT  \
# km_cluster
# 0            88.587827  0.107556  0.357738   11.578227  0.108637  0.151690
# 1           107.955536  0.116050  1.052288   10.408884  0.532793  0.564298
# 2           108.280180  0.109196  0.533526   10.208237  0.681038  0.704751
# 3           108.502866  0.227848  2.110800    9.663895  0.495281  0.533972
#
#                  POSS
# km_cluster
# 0           23.269233
# 1           59.838961
# 2           36.371170
# 3           64.663685

# %%
pca_km_df.groupby(['km_cluster'])[pg_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   AST_TOV  AST_RATIO   EFG_PCT    TS_PCT  \
# km_cluster
# 0            88.587827  0.107556  0.357738  15.035271  0.108637  0.151690
# 1           107.955536  0.116050  1.052288  14.037452  0.532793  0.564298
# 2           108.280180  0.109196  0.533526  13.264692  0.681038  0.704751
# 3           108.502866  0.227848  2.110800  22.352153  0.495281  0.533972
#
#                  POSS
# km_cluster
# 0           23.269233
# 1           59.838961
# 2           36.371170
# 3           64.663685

# %%
pca_km_df.groupby(['km_cluster'])[sf_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   EFG_PCT    TS_PCT       POSS
# km_cluster
# 0            88.587827  0.107556  0.108637  0.151690  23.269233
# 1           107.955536  0.116050  0.532793  0.564298  59.838961
# 2           108.280180  0.109196  0.681038  0.704751  36.371170
# 3           108.502866  0.227848  0.495281  0.533972  64.663685

# %%
x_axis = pca_km_df['pca_1']
y_axis = pca_km_df['pca_2']

plt.figure(figsize=(10, 8))
sns.scatterplot(x=x_axis, y=y_axis, hue=pca_km_df['km_cluster'], palette=['r', 'g', 'b', 'c'])
plt.title("Clusters with K-Means Visualized on PCA Components")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %%
pca_km_df.groupby(['km_cluster'])[pf_group_1].agg("mean")
# Out:
#             OFF_RATING   EFG_PCT    TS_PCT       POSS   USG_PCT
# km_cluster
# 0            88.587827  0.108637  0.151690  23.269233  0.142489
# 1           107.955536  0.532793  0.564298  59.838961  0.192407
# 2           108.280180  0.681038  0.704751  36.371170  0.183326
# 3           108.502866  0.495281  0.533972  64.663685  0.215013

# %%
pca_km_df.groupby(['km_cluster'])[c_group_1].agg("mean")
# Out:
#             DEF_RATING  OREB_PCT  DREB_PCT   REB_PCT       POSS
# km_cluster
# 0           104.826522  0.032348  0.120644  0.075594  23.269233
# 1           108.097292  0.055398  0.171432  0.113552  59.838961
# 2           105.772973  0.045988  0.136678  0.092215  36.371170
# 3           107.650595  0.022480  0.106086  0.064280  64.663685

# %% [markdown]
# # Gaussian Mixture Models

# %%
from sklearn.mixture import GaussianMixture
from sklearn.mixture import BayesianGaussianMixture

# %%
gm_df = data_2015_2021.copy()

# %%
# find the optimum number of clusters
bgm = BayesianGaussianMixture(n_components=10, n_init=7, max_iter=1000)
bgm.fit(pca_scores)
np.round(bgm.weights_, 2)
# Out:
# array([0.16, 0.09, 0.18, 0.15, 0.03, 0.07, 0.01, 0.06, 0.18, 0.06])

# %% [markdown]
# It returned weights of clusters

# %%
# Instantiate a GM model with 4 clusters, fit and predict cluster indices
gm = GaussianMixture(n_components=4, init_params='kmeans', tol=1e-4,
                     covariance_type='full', n_init=10, random_state=1)
gm_df['gm_cluster'] = gm.fit_predict(pca_scores)

# %%
pca_gm_df = pd.concat([gm_df.reset_index(drop=True), pd.DataFrame(
    data=pca_scores, columns=['pca_1', 'pca_2', 'pca_3', 'pca_4'])], axis=1)
pca_gm_df.head()
# Out:
#   START_POSITION   MIN  OFF_RATING  DEF_RATING  AST_PCT  AST_TOV  AST_RATIO  \
# 0              2  2809       103.4        97.7    0.458      2.2       25.0
# 1              2  1802       120.0        87.0    0.150      3.0       20.0
# 2              3  1909       100.0        96.7    0.000      0.0        0.0
# 3              1  2335       113.7       102.7    0.087      1.0       11.8
# 4              1  2580       108.8        96.3    0.050      0.5        3.7
#
#    OREB_PCT  DREB_PCT  REB_PCT  ...  USG_PCT   PACE  PACE_PER40  POSS    PIE  \
# 0     0.020     0.192    0.109  ...    0.330  89.71       74.75    87  0.190
# 1     0.129     0.294    0.215  ...    0.179  87.10       72.59    55  0.180
# 2     0.000     0.083    0.043  ...    0.074  92.05       76.71    61  0.073
# 3     0.000     0.093    0.047  ...    0.176  90.66       75.55    73  0.043
# 4     0.065     0.064    0.065  ...    0.277  89.30       74.42    80  0.109
#
#    gm_cluster     pca_1     pca_2     pca_3     pca_4
# 0           1  0.572885 -0.080019  0.390113  0.114654
# 1           1  0.385601 -0.214780  0.036019 -0.063064
# 2           1  0.784950  0.161279 -0.342901 -0.064941
# 3           3  0.188411 -0.000870  0.095659  0.276210
# 4           3  0.237746  0.044494  0.051963  0.384982
#
# [5 rows x 23 columns]

# %%
# check for the clusters' balance
pca_gm_df.gm_cluster.value_counts()
# Out:
# gm_cluster
# 0    83023
# 1    52314
# 3    34475
# 2    17993
# Name: count, dtype: int64

# %%
pca_gm_df.groupby(['gm_cluster'])[sg_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   AST_TOV  TM_TOV_PCT   EFG_PCT    TS_PCT  \
# gm_cluster
# 0           105.195764  0.125561  0.727033    9.962477  0.546290  0.585972
# 1           107.896955  0.116800  1.055633   10.420193  0.530261  0.561821
# 2            81.178319  0.095893  0.167899   13.061785  0.000000  0.000011
# 3           108.315011  0.218341  1.972851   10.150503  0.503984  0.541179
#
#                  POSS
# gm_cluster
# 0           38.129591
# 1           59.594124
# 2           13.166120
# 3           64.174938

# %% [markdown]
# The cluster 3 is more suitable for the shooting guard position, as it exhibits higher mean values for the features compared to the other clusters.

# %%
pca_gm_df.groupby(['gm_cluster'])[pg_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   AST_TOV  AST_RATIO   EFG_PCT    TS_PCT  \
# gm_cluster
# 0           105.195764  0.125561  0.727033  14.892638  0.546290  0.585972
# 1           107.896955  0.116800  1.055633  14.122938  0.530261  0.561821
# 2            81.178319  0.095893  0.167899  15.825727  0.000000  0.000011
# 3           108.315011  0.218341  1.972851  20.916125  0.503984  0.541179
#
#                  POSS
# gm_cluster
# 0           38.129591
# 1           59.594124
# 2           13.166120
# 3           64.174938

# %% [markdown]
# The cluster 3 is more suitable for the point_guard position, as it exhibits higher mean values for the features compared to the other clusters.

# %%
pca_gm_df.groupby(['gm_cluster'])[sf_group_1].agg("mean")
# Out:
#             OFF_RATING   AST_PCT   EFG_PCT    TS_PCT       POSS
# gm_cluster
# 0           105.195764  0.125561  0.546290  0.585972  38.129591
# 1           107.896955  0.116800  0.530261  0.561821  59.594124
# 2            81.178319  0.095893  0.000000  0.000011  13.166120
# 3           108.315011  0.218341  0.503984  0.541179  64.174938

# %% [markdown]
# The cluster 3 is more suitable for the small forward position, as it exhibits higher mean values for the features compared to the other clusters.

# %%
pca_gm_df.groupby(['gm_cluster'])[pf_group_1].agg("mean")
# Out:
#             OFF_RATING   EFG_PCT    TS_PCT       POSS   USG_PCT
# gm_cluster
# 0           105.195764  0.546290  0.585972  38.129591  0.183526
# 1           107.896955  0.530261  0.561821  59.594124  0.192320
# 2            81.178319  0.000000  0.000011  13.166120  0.100274
# 3           108.315011  0.503984  0.541179  64.174938  0.219394

# %% [markdown]
# The cluster 1 is more suitable for the power forward, as it exhibits higher mean values for the features compared to the other clusters.

# %%
pca_gm_df.groupby(['gm_cluster'])[c_group_1].agg("mean")
# Out:
#             DEF_RATING  OREB_PCT  DREB_PCT   REB_PCT       POSS
# gm_cluster
# 0           105.582015  0.042863  0.131915  0.087490  38.129591
# 1           108.131311  0.055428  0.172748  0.114274  59.594124
# 2           104.004502  0.024800  0.114823  0.070006  13.166120
# 3           108.304336  0.020543  0.101872  0.061203  64.174938

# %% [markdown]
# The cluster 1 is more suitable for the center, as it exhibits higher mean values for the features compared to the other clusters.

# %%
#Visualize clusters
x_axis = pca_gm_df['pca_1']
y_axis = pca_gm_df['pca_2']

plt.figure(figsize=(10, 8))
sns.scatterplot(x=x_axis, y=y_axis, hue=pca_gm_df['gm_cluster'], palette=['r', 'g', 'b', 'c'])
plt.title("Clusters with GMMs Visualized on PCA Components")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# Now cluster 3 and 0 is seperated better than other clusters compared to kmeans clustering

# %%
import numpy as np
from sklearn.metrics import accuracy_score

def train_model(df, folds, features, model):
    
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    
    scores = []
    
    fold_size = len(df) // folds

    for fold in range(folds):
        start = fold * fold_size
        end = (fold + 1) * fold_size if fold != folds - 1 else len(df)
        
        df_valid = df[start:end].reset_index(drop=True)
        
        df_train = pd.concat([df[:start], df[end:]], axis=0).reset_index(drop=True)

        X_train, y_train = df_train[features].values, df_train['gm_cluster'].values
        X_valid, y_valid = df_valid[features].values, df_valid['gm_cluster'].values

        model.fit(X_train, y_train)

        valid_preds = model.predict(X_valid)

        accuracy = accuracy_score(y_valid, valid_preds)

        print(f"Fold {fold}, Accuracy: {accuracy:.4f}")

        scores.append(accuracy)

    mean_accuracy = np.mean(scores)

    print(f"Mean Accuracy: {mean_accuracy:.4f}")
    
    return mean_accuracy

# %%
def feat_permutation_importance(df, features, model):
    X = df[features]
    y = df["gm_cluster"]

    model = model

    model.fit(X, y)

    results = permutation_importance(model, X, y, scoring='f1_weighted')

    importance = results.importances_mean
    idxs = np.argsort(importance)
    importances = pd.Series(importance, index=features)

    plt.title('Permutation Feature Importance', fontsize=12)
    plt.barh(range(len(idxs)), importances.iloc[idxs], align='center')
    plt.yticks(range(len(idxs)), [features[i] for i in idxs])
    plt.xlabel('Feature Importance')
    plt.show()

    return importances

# %%
from sklearn.feature_selection import RFE

def rfe_feature_selection(df, features,num_features_to_select, model):
    X = df[features]
    y = df["gm_cluster"]
    
    model = model
    
    rfe = RFE(estimator=model, n_features_to_select=num_features_to_select)
    
    rfe.fit(X, y)
    
    selected_features = [features[i] for i in range(len(features)) if rfe.support_[i]]
    
    rankings = pd.DataFrame({
        'Feature': features,
        'Ranking': rfe.ranking_
    }).sort_values(by='Ranking')
    
    return selected_features, rankings

# %%
def rfe_with_cv(df, features, model):
    X = df[features]
    y = df['gm_cluster']
    
    model = model
    results = {}
    
    for num_features in range(1, len(features)+1):
        rfe = RFE(estimator=model, n_features_to_select=num_features)
        rfe.fit(X, y)
        
        selected_features = [features[i] for i in range(len(features)) if rfe.support_[i]]
        score = cross_val_score(model, X[selected_features], y, cv=5, scoring='accuracy')
        
        results[num_features] = np.mean(score)
    
    return results

# %%
def compare_lists(l1, l2):
    return [j for i, j in zip(l1, l2) if i == True]

# %%
train_df = df_2015_2021.copy()
# Merge gm_df and train_df
train_df = train_df.merge(gm_df[['gm_cluster']], left_index=True, right_index=True, how='left')

train_df.head()
# Out:
#     GAME_ID  GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407 2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407 2016-06-19  1610612739               CLE  Cleveland     201567
# 2  41500407 2016-06-19  1610612739               CLE  Cleveland     202684
# 3  41500407 2016-06-19  1610612739               CLE  Cleveland       2747
# 4  41500407 2016-06-19  1610612739               CLE  Cleveland     202681
#
#         PLAYER_NAME NICKNAME START_POSITION   MIN  ...  REB_PCT  TM_TOV_PCT  \
# 0      LeBron James   LeBron              2  2809  ...    0.109        11.4
# 1        Kevin Love    Kevin              2  1802  ...    0.215         6.7
# 2  Tristan Thompson  Tristan              3  1909  ...    0.043         0.0
# 3          JR Smith       JR              1  2335  ...    0.047        11.8
# 4      Kyrie Irving    Kyrie              1  2580  ...    0.065         7.4
#
#    EFG_PCT  TS_PCT  USG_PCT   PACE  PACE_PER40  POSS    PIE  gm_cluster
# 0    0.396   0.475    0.330  89.71       74.75    87  0.190           1
# 1    0.333   0.418    0.179  87.10       72.59    55  0.180           1
# 2    1.000   0.945    0.074  92.05       76.71    61  0.073           1
# 3    0.462   0.462    0.176  90.66       75.55    73  0.043           3
# 4    0.478   0.525    0.277  89.30       74.42    80  0.109           3
#
# [5 rows x 27 columns]

# %%
train_features = [
    col
    for col in df.columns
    if col
    not in (
        "GAME_ID",
        "TEAM_ID",
        "TEAM_ABBREVIATION",
        "TEAM_CITY",
        "PLAYER_ID",
        "PLAYER_NAME",
        "NICKNAME",
        "GAME_DATE",
        "gm_cluster",
    )
]
train_features
# Out:
# ['START_POSITION',
#  'MIN',
#  'OFF_RATING',
#  'DEF_RATING',
#  'AST_PCT',
#  'AST_TOV',
#  'AST_RATIO',
#  'OREB_PCT',
#  'DREB_PCT',
#  'REB_PCT',
#  'TM_TOV_PCT',
#  'EFG_PCT',
#  'TS_PCT',
#  'USG_PCT',
#  'PACE',
#  'PACE_PER40',
#  'POSS',
#  'PIE']

# %%
#Values to be scaled.
train_data = train_df[features].values

# %%
train_data = train_df[features].values
# initialize scaler
scaler = MinMaxScaler()

# fit scaler
scaler.fit(train_data)

# transform data
train_data_scaled = scaler.transform(train_data)

# %%
train_norm_features = [feat+'_n' for feat in train_features]

# %%
train_norm_df = pd.concat([train_df.reset_index(drop=True), pd.DataFrame(
    data=train_data_scaled, columns=train_norm_features)], axis=1)
train_norm_df.head()
# Out:
#     GAME_ID  GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407 2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407 2016-06-19  1610612739               CLE  Cleveland     201567
# 2  41500407 2016-06-19  1610612739               CLE  Cleveland     202684
# 3  41500407 2016-06-19  1610612739               CLE  Cleveland       2747
# 4  41500407 2016-06-19  1610612739               CLE  Cleveland     202681
#
#         PLAYER_NAME NICKNAME START_POSITION   MIN  ...  DREB_PCT_n  REB_PCT_n  \
# 0      LeBron James   LeBron              2  2809  ...       0.192      0.109
# 1        Kevin Love    Kevin              2  1802  ...       0.294      0.215
# 2  Tristan Thompson  Tristan              3  1909  ...       0.083      0.043
# 3          JR Smith       JR              1  2335  ...       0.093      0.047
# 4      Kyrie Irving    Kyrie              1  2580  ...       0.064      0.065
#
#    TM_TOV_PCT_n  EFG_PCT_n  TS_PCT_n  USG_PCT_n    PACE_n  PACE_PER40_n  \
# 0         0.114   0.264000  0.316667      0.330  0.006227      0.006227
# 1         0.067   0.222000  0.278667      0.179  0.006046      0.006047
# 2         0.000   0.666667  0.630000      0.074  0.006390      0.006390
# 3         0.118   0.308000  0.308000      0.176  0.006293      0.006293
# 4         0.074   0.318667  0.350000      0.277  0.006199      0.006199
#
#      POSS_n     PIE_n
# 0  0.719008  0.616957
# 1  0.454545  0.616522
# 2  0.504132  0.611870
# 3  0.603306  0.610565
# 4  0.661157  0.613435
#
# [5 rows x 45 columns]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# initialize Logistic Regression model
logres = LogisticRegression(max_iter = 1000,
    solver='lbfgs',
    n_jobs=-1)

# %%
train_model(train_norm_df, 5, train_norm_features, logres)
# Out:
# Fold 0, Accuracy: 0.9964
# Fold 1, Accuracy: 0.9964
# Fold 2, Accuracy: 0.9962
# Fold 3, Accuracy: 0.9968
# Fold 4, Accuracy: 0.9962
# Mean Accuracy: 0.9964
# 0.9964271451771785

# %% [markdown]
# We have good accuracy score, but it's too high. We need to check feature importances

# %%
from sklearn.inspection import permutation_importance
feat_permutation_importance(train_norm_df, train_norm_features, logres)
# Out:
# START_POSITION_n    0.582557
# MIN_n               0.014328
# OFF_RATING_n        0.000188
# DEF_RATING_n       -0.000048
# AST_PCT_n           0.000099
# AST_TOV_n          -0.000085
# AST_RATIO_n         0.001227
# OREB_PCT_n          0.000145
# DREB_PCT_n          0.002386
# REB_PCT_n           0.000583
# TM_TOV_PCT_n        0.000044
# EFG_PCT_n           0.043833
# TS_PCT_n            0.107029
# USG_PCT_n           0.001248
# PACE_n              0.000000
# PACE_PER40_n        0.000000
# POSS_n              0.028862
# PIE_n               0.000008
# dtype: float64

# %%
train_model(train_norm_df, 5, ['START_POSITION_n'], logres)
# Out:
# Fold 0, Accuracy: 0.9018
# Fold 1, Accuracy: 0.8995
# Fold 2, Accuracy: 0.9033
# Fold 3, Accuracy: 0.9045
# Fold 4, Accuracy: 0.9046
# Mean Accuracy: 0.9027
# 0.9027288943318869

# %% [markdown]
# Using the `START_POSITION_n` feature alone, we achieved an impressive accuracy of 90% in our logistic regression model. However, this feature dominates the model and causes overfitting, as it outperforms the other features significantly.

# %% [markdown]
# We encoded unknown positions as 0.

# %%
# Re-define norm_features
train_norm_features.remove('START_POSITION_n')

# %%
feat_permutation_importance(train_norm_df, train_norm_features, logres)
# Out:
# MIN_n           0.246143
# OFF_RATING_n    0.001047
# DEF_RATING_n    0.003757
# AST_PCT_n       0.032034
# AST_TOV_n       0.000058
# AST_RATIO_n     0.004903
# OREB_PCT_n      0.008125
# DREB_PCT_n      0.010680
# REB_PCT_n       0.029990
# TM_TOV_PCT_n    0.002317
# EFG_PCT_n       0.069201
# TS_PCT_n        0.114949
# USG_PCT_n       0.011074
# PACE_n         -0.000001
# PACE_PER40_n   -0.000001
# POSS_n          0.060658
# PIE_n          -0.000096
# dtype: float64

# %% [markdown]
# The less time a player spends on the court, the lower the chance of achieving significant records (e.g., passes, points, etc.). The `MIN` variable directly represents the time a player spent on the court, making it a potential confounding factor. Therefore, we must consider ignoring it in our analysis.

# %%
# Re-define norm_features
train_norm_features.remove('MIN_n')

# %%
feat_permutation_importance(train_norm_df, train_norm_features, logres)
# Out:
# OFF_RATING_n    0.000463
# DEF_RATING_n    0.003475
# AST_PCT_n       0.031784
# AST_TOV_n       0.000012
# AST_RATIO_n     0.004271
# OREB_PCT_n      0.006984
# DREB_PCT_n      0.007962
# REB_PCT_n       0.033282
# TM_TOV_PCT_n    0.001464
# EFG_PCT_n       0.077377
# TS_PCT_n        0.116426
# USG_PCT_n       0.010917
# PACE_n          0.000023
# PACE_PER40_n    0.000023
# POSS_n          0.269658
# PIE_n          -0.000007
# dtype: float64

# %%
# re-define feats
train_features.remove('START_POSITION')
train_features.remove('MIN')

# %%
train_df[train_features].shape
# Out:
# (187805, 16)

# %%
train_data = train_df[train_features].values

# %%
# initialize scaler
scaler = MinMaxScaler()

# fit scaler
scaler.fit(train_data)

# transform data
train_data_scaled = scaler.transform(train_data)

# %%
train_norm_df = pd.concat([train_df.reset_index(drop=True), pd.DataFrame(
    data=train_data_scaled, columns=train_norm_features)], axis=1)
train_norm_df.head()
# Out:
#     GAME_ID  GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407 2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407 2016-06-19  1610612739               CLE  Cleveland     201567
# 2  41500407 2016-06-19  1610612739               CLE  Cleveland     202684
# 3  41500407 2016-06-19  1610612739               CLE  Cleveland       2747
# 4  41500407 2016-06-19  1610612739               CLE  Cleveland     202681
#
#         PLAYER_NAME NICKNAME START_POSITION   MIN  ...  DREB_PCT_n  REB_PCT_n  \
# 0      LeBron James   LeBron              2  2809  ...       0.192      0.109
# 1        Kevin Love    Kevin              2  1802  ...       0.294      0.215
# 2  Tristan Thompson  Tristan              3  1909  ...       0.083      0.043
# 3          JR Smith       JR              1  2335  ...       0.093      0.047
# 4      Kyrie Irving    Kyrie              1  2580  ...       0.064      0.065
#
#    TM_TOV_PCT_n  EFG_PCT_n  TS_PCT_n  USG_PCT_n    PACE_n  PACE_PER40_n  \
# 0         0.114   0.264000  0.316667      0.330  0.006227      0.006227
# 1         0.067   0.222000  0.278667      0.179  0.006046      0.006047
# 2         0.000   0.666667  0.630000      0.074  0.006390      0.006390
# 3         0.118   0.308000  0.308000      0.176  0.006293      0.006293
# 4         0.074   0.318667  0.350000      0.277  0.006199      0.006199
#
#      POSS_n     PIE_n
# 0  0.719008  0.616957
# 1  0.454545  0.616522
# 2  0.504132  0.611870
# 3  0.603306  0.610565
# 4  0.661157  0.613435
#
# [5 rows x 43 columns]

# %% [markdown]
# # PCA

# %%
train_data_pca = train_norm_df.loc[:, train_norm_features].values

# %%
pca = PCA()
pca.fit(train_data_pca)
pca.explained_variance_ratio_
# Out:
# array([3.58783447e-01, 2.12273717e-01, 1.29659408e-01, 8.51576338e-02,
#        7.71067881e-02, 4.59591515e-02, 2.20933801e-02, 1.79304660e-02,
#        1.73223744e-02, 1.14613716e-02, 1.12164957e-02, 9.35085349e-03,
#        1.15070224e-03, 3.31486706e-04, 2.02724371e-04, 2.40130977e-13])

# %%
# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Compute the cumulative sum of explained variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()

# Plot the cumulative variance
ax.plot(np.arange(1, len(cumulative_variance) + 1), cumulative_variance, 
        marker='o', linestyle='--', color='b')

# Add labels and title
ax.set_title('Cumulative Explained Variance by Number of Components', fontsize=14)
ax.set_xlabel('Number of Principal Components', fontsize=12)
ax.set_ylabel('Cumulative Explained Variance', fontsize=12)

# Show grid for better readability
ax.grid(True, linestyle='--', alpha=0.6)

# Display the plot
plt.show()

# %%
# choose 9, retaining almost all the variance level
pca = PCA(n_components=7)
pca.fit(train_data_pca)
train_pca_scores = pca.transform(train_data_pca)

# %% [markdown]
# We can choose any number of component above 6, since it will explain more than %90 of variance. We choose 7 as optimal numbers of components.

# %%
train_norm_pca_df = pd.concat([train_norm_df.reset_index(drop=True), pd.DataFrame(
    data=train_pca_scores, columns=['pca_1', 'pca_2', 'pca_3', 'pca_4', 'pca_5', 'pca_6', 'pca_7'])], axis=1)

# %%
train_pca_features = ["pca_"+f"{i}" for i in range(1, 8)]

# %%
train_norm_pca_df.head()
# Out:
#     GAME_ID  GAME_DATE     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  41500407 2016-06-19  1610612739               CLE  Cleveland       2544
# 1  41500407 2016-06-19  1610612739               CLE  Cleveland     201567
# 2  41500407 2016-06-19  1610612739               CLE  Cleveland     202684
# 3  41500407 2016-06-19  1610612739               CLE  Cleveland       2747
# 4  41500407 2016-06-19  1610612739               CLE  Cleveland     202681
#
#         PLAYER_NAME NICKNAME START_POSITION   MIN  ...  PACE_PER40_n  \
# 0      LeBron James   LeBron              2  2809  ...      0.006227
# 1        Kevin Love    Kevin              2  1802  ...      0.006047
# 2  Tristan Thompson  Tristan              3  1909  ...      0.006390
# 3          JR Smith       JR              1  2335  ...      0.006293
# 4      Kyrie Irving    Kyrie              1  2580  ...      0.006199
#
#      POSS_n     PIE_n     pca_1     pca_2     pca_3     pca_4     pca_5  \
# 0  0.719008  0.616957  0.090774  0.389464  0.233453  0.088523 -0.002121
# 1  0.454545  0.616522 -0.062935  0.096020  0.087436  0.129385 -0.180478
# 2  0.504132  0.611870  0.425987 -0.240465  0.036700 -0.174419 -0.014170
# 3  0.603306  0.610565  0.029798  0.026114  0.218617 -0.061164  0.046774
# 4  0.661157  0.613435  0.082437 -0.040666  0.302849 -0.090352  0.027268
#
#       pca_6     pca_7
# 0  0.161795 -0.039226
# 1 -0.019063  0.069420
# 2 -0.082939 -0.092718
# 3 -0.053354 -0.011794
# 4  0.036895  0.047221
#
# [5 rows x 50 columns]

# %%
# initialize Logistic Regression model for train_norm_pca_df
logres = LogisticRegression(max_iter = 1000,
    solver='lbfgs',
    n_jobs=-1)

# %%
feat_permutation_importance(train_norm_pca_df, train_norm_features, logres)
# Out:
# OFF_RATING_n    0.000532
# DEF_RATING_n    0.003566
# AST_PCT_n       0.032401
# AST_TOV_n      -0.000095
# AST_RATIO_n     0.004288
# OREB_PCT_n      0.007218
# DREB_PCT_n      0.007984
# REB_PCT_n       0.034050
# TM_TOV_PCT_n    0.001462
# EFG_PCT_n       0.076792
# TS_PCT_n        0.115721
# USG_PCT_n       0.010821
# PACE_n          0.000028
# PACE_PER40_n    0.000028
# POSS_n          0.269923
# PIE_n           0.000067
# dtype: float64

# %% [markdown]
# We stil have many features and removing some of them can increase signifance of others.

# %%
selected_features, ranks = rfe_feature_selection(train_norm_pca_df, train_norm_features, 12, logres)
print(ranks)
# Out:
#          Feature  Ranking
# 0   OFF_RATING_n        1
# 1   DEF_RATING_n        1
# 2      AST_PCT_n        1
# 4    AST_RATIO_n        1
# 5     OREB_PCT_n        1
# 6     DREB_PCT_n        1
# 7      REB_PCT_n        1
# 9      EFG_PCT_n        1
# 10      TS_PCT_n        1
# 11     USG_PCT_n        1
# 14        POSS_n        1
# 15         PIE_n        1
# 13  PACE_PER40_n        2
# 8   TM_TOV_PCT_n        3
# 12        PACE_n        4
# 3      AST_TOV_n        5

# %%
train_model(train_norm_pca_df, 5, selected_features, logres)
# Out:
# Fold 0, Accuracy: 0.7242
# Fold 1, Accuracy: 0.7187
# Fold 2, Accuracy: 0.7190
# Fold 3, Accuracy: 0.7189
# Fold 4, Accuracy: 0.7170
# Mean Accuracy: 0.7195
# 0.7195495327600436

# %%
selected_features, ranks = rfe_feature_selection(train_norm_pca_df, train_norm_features, 8, logres)
print(ranks)
# Out:
#          Feature  Ranking
# 1   DEF_RATING_n        1
# 5     OREB_PCT_n        1
# 7      REB_PCT_n        1
# 9      EFG_PCT_n        1
# 10      TS_PCT_n        1
# 11     USG_PCT_n        1
# 14        POSS_n        1
# 15         PIE_n        1
# 2      AST_PCT_n        2
# 0   OFF_RATING_n        3
# 6     DREB_PCT_n        4
# 4    AST_RATIO_n        5
# 13  PACE_PER40_n        6
# 8   TM_TOV_PCT_n        7
# 12        PACE_n        8
# 3      AST_TOV_n        9

# %%
train_model(train_norm_pca_df, 5, selected_features, logres)
# Out:
# Fold 0, Accuracy: 0.7096
# Fold 1, Accuracy: 0.7063
# Fold 2, Accuracy: 0.7080
# Fold 3, Accuracy: 0.7049
# Fold 4, Accuracy: 0.7068
# Mean Accuracy: 0.7071
# 0.7071270732941082

# %%
train_norm_selected_features, ranks = rfe_feature_selection(train_norm_pca_df, train_norm_features, 12, logres)

# Remove the '_n' suffix from the selected features
train_selected_features = [feature.replace('_n', '') for feature in train_norm_selected_features]

print(train_selected_features)
# Out:
# ['OFF_RATING', 'DEF_RATING', 'AST_PCT', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT', 'POSS', 'PIE']

# %%
# define a grid of parameters
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
# initialize grid search
# estimator is the model that we have defined
# we use f1_weighted as our metric
# cv=5 means that we are using 5 fold cv
from sklearn import model_selection
model = model_selection.GridSearchCV(
    estimator=logres,
    param_grid=param_grid,
    scoring="f1_weighted",
    verbose=10,
    n_jobs=1,
    cv=5
)

# %%
X = train_norm_pca_df[train_norm_selected_features].values
y = train_norm_pca_df.gm_cluster.values

# %%
# fit model on training data
model.fit(X, y)

print(f"Best score: {model.best_score_}")

print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START C=0.001.....................................................
# [CV 1/5; 1/6] END ......................C=0.001;, score=0.628 total time=   1.4s
# [CV 2/5; 1/6] START C=0.001.....................................................
# [CV 2/5; 1/6] END ......................C=0.001;, score=0.627 total time=   1.5s
# [CV 3/5; 1/6] START C=0.001.....................................................
# [CV 3/5; 1/6] END ......................C=0.001;, score=0.635 total time=   1.5s
# [CV 4/5; 1/6] START C=0.001.....................................................
# [CV 4/5; 1/6] END ......................C=0.001;, score=0.634 total time=   1.5s
# [CV 5/5; 1/6] START C=0.001.....................................................
# [CV 5/5; 1/6] END ......................C=0.001;, score=0.635 total time=   1.5s
# [CV 1/5; 2/6] START C=0.01......................................................
# [CV 1/5; 2/6] END .......................C=0.01;, score=0.702 total time=   1.8s
# [CV 2/5; 2/6] START C=0.01......................................................
# [CV 2/5; 2/6] END .......................C=0.01;, score=0.702 total time=   1.8s
# [CV 3/5; 2/6] START C=0.01......................................................
# [CV 3/5; 2/6] END .......................C=0.01;, score=0.704 total time=   1.8s
# [CV 4/5; 2/6] START C=0.01......................................................
# [CV 4/5; 2/6] END .......................C=0.01;, score=0.701 total time=   1.6s
# [CV 5/5; 2/6] START C=0.01......................................................
# [CV 5/5; 2/6] END .......................C=0.01;, score=0.710 total time=   1.9s
# [CV 1/5; 3/6] START C=0.1.......................................................
# [CV 1/5; 3/6] END ........................C=0.1;, score=0.710 total time=   2.2s
# [CV 2/5; 3/6] START C=0.1.......................................................
# [CV 2/5; 3/6] END ........................C=0.1;, score=0.709 total time=   2.3s
# [CV 3/5; 3/6] START C=0.1.......................................................
# [CV 3/5; 3/6] END ........................C=0.1;, score=0.712 total time=   2.5s
# [CV 4/5; 3/6] START C=0.1.......................................................
# [CV 4/5; 3/6] END ........................C=0.1;, score=0.708 total time=   2.0s
# [CV 5/5; 3/6] START C=0.1.......................................................
# [CV 5/5; 3/6] END ........................C=0.1;, score=0.721 total time=   2.2s
# [CV 1/5; 4/6] START C=1.........................................................
# [CV 1/5; 4/6] END ..........................C=1;, score=0.712 total time=   2.3s
# [CV 2/5; 4/6] START C=1.........................................................
# [CV 2/5; 4/6] END ..........................C=1;, score=0.712 total time=   2.4s
# [CV 3/5; 4/6] START C=1.........................................................
# [CV 3/5; 4/6] END ..........................C=1;, score=0.714 total time=   2.3s
# [CV 4/5; 4/6] START C=1.........................................................
# [CV 4/5; 4/6] END ..........................C=1;, score=0.710 total time=   2.4s
# [CV 5/5; 4/6] START C=1.........................................................
# [CV 5/5; 4/6] END ..........................C=1;, score=0.725 total time=   3.0s
# [CV 1/5; 5/6] START C=10........................................................
# [CV 1/5; 5/6] END .........................C=10;, score=0.713 total time=   2.5s
# [CV 2/5; 5/6] START C=10........................................................
# [CV 2/5; 5/6] END .........................C=10;, score=0.712 total time=   2.8s
# [CV 3/5; 5/6] START C=10........................................................
# [CV 3/5; 5/6] END .........................C=10;, score=0.715 total time=   3.3s
# [CV 4/5; 5/6] START C=10........................................................
# [CV 4/5; 5/6] END .........................C=10;, score=0.710 total time=   3.0s
# [CV 5/5; 5/6] START C=10........................................................
# [CV 5/5; 5/6] END .........................C=10;, score=0.726 total time=   2.4s
# [CV 1/5; 6/6] START C=100.......................................................
# [CV 1/5; 6/6] END ........................C=100;, score=0.712 total time=   3.4s
# [CV 2/5; 6/6] START C=100.......................................................
# [CV 2/5; 6/6] END ........................C=100;, score=0.713 total time=   2.6s
# [CV 3/5; 6/6] START C=100.......................................................
# [CV 3/5; 6/6] END ........................C=100;, score=0.715 total time=   3.1s
# [CV 4/5; 6/6] START C=100.......................................................
# [CV 4/5; 6/6] END ........................C=100;, score=0.711 total time=   3.6s
# [CV 5/5; 6/6] START C=100.......................................................
# [CV 5/5; 6/6] END ........................C=100;, score=0.725 total time=   3.3s
# Best score: 0.7151094663220918
# Best parameters set:
# 	C: 100

# %%
# initialize tuned Logistic Regression model
tuned_logres = LogisticRegression(max_iter = 1000,
    C=100,
    solver='lbfgs',
    n_jobs=-1)

# %%
train_model(train_norm_pca_df, 5, train_norm_selected_features, tuned_logres)
# Out:
# Fold 0, Accuracy: 0.7244
# Fold 1, Accuracy: 0.7189
# Fold 2, Accuracy: 0.7195
# Fold 3, Accuracy: 0.7199
# Fold 4, Accuracy: 0.7172
# Mean Accuracy: 0.7200
# 0.7199701818375442

# %%
train_model(train_norm_pca_df, 5, train_pca_features, tuned_logres)
# Out:
# Fold 0, Accuracy: 0.7217
# Fold 1, Accuracy: 0.7141
# Fold 2, Accuracy: 0.7152
# Fold 3, Accuracy: 0.7145
# Fold 4, Accuracy: 0.7153
# Mean Accuracy: 0.7161
# 0.7161470674369692

# %% [markdown]
# # Light GBM

# %%
# Initialize the LightGBM Classifier
import lightgbm as lgb
lgb_clf = lgb.LGBMClassifier(n_jobs=-1, verbose = -1)

# %%
train_model(train_norm_pca_df, 5, train_features, lgb_clf)
# Out:
# Fold 0, Accuracy: 0.7385
# Fold 1, Accuracy: 0.7316
# Fold 2, Accuracy: 0.7340
# Fold 3, Accuracy: 0.7309
# Fold 4, Accuracy: 0.7298
# Mean Accuracy: 0.7330
# 0.7329517318495247

# %%
train_model(train_norm_pca_df, 5, train_norm_selected_features, lgb_clf)
# Out:
# Fold 0, Accuracy: 0.7333
# Fold 1, Accuracy: 0.7281
# Fold 2, Accuracy: 0.7287
# Fold 3, Accuracy: 0.7269
# Fold 4, Accuracy: 0.7251
# Mean Accuracy: 0.7284
# 0.7284151114187588

# %%
param_grid = {
    "num_leaves": [31, 50],  # Number of leaves in the tree (higher values can make the model more complex)
    "learning_rate": [0.05, 0.1],  # Learning rate (lower values require more boosting rounds)
    "n_estimators": [100, 150, 200],  # Number of boosting rounds (trees)
    "max_depth": [-1, 5],  # Maximum depth of the tree, -1 means no limit
    "min_child_samples": [20, 30],  # Minimum number of data points in a leaf
    "colsample_bytree": [0.8, 1.0],  # Fraction of features to consider for each tree
    "subsample": [0.8, 1.0],  # Fraction of data to be used for fitting each tree (to prevent overfitting)
}

# %%
from sklearn.model_selection import GridSearchCV
# initialize grid search

# we use f1 as our metric
# cv=5 means that we are using 5 fold cv
model = model_selection.GridSearchCV(
    estimator=lgb_clf,
    param_grid=param_grid,
    scoring="f1_weighted",
    verbose=10,
    n_jobs=1,
    cv=5
)

# %%
# fit model on training data
model.fit(X, y)

# get best score
print(f"Best score: {model.best_score_}")

# get best params
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5; 1/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 1/5; 1/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.5s
# [CV 2/5; 1/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 2/5; 1/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.5s
# [CV 3/5; 1/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 3/5; 1/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.721 total time=   1.4s
# [CV 4/5; 1/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 4/5; 1/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.3s
# [CV 5/5; 1/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 5/5; 1/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.732 total time=   1.4s
# [CV 1/5; 2/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 1/5; 2/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.5s
# [CV 2/5; 2/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 2/5; 2/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.5s
# [CV 3/5; 2/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 3/5; 2/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.721 total time=   1.5s
# [CV 4/5; 2/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 4/5; 2/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.717 total time=   1.6s
# [CV 5/5; 2/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 5/5; 2/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.732 total time=   1.4s
# [CV 1/5; 3/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 1/5; 3/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.719 total time=   1.9s
# [CV 2/5; 3/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 2/5; 3/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.718 total time=   1.7s
# [CV 3/5; 3/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 3/5; 3/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.722 total time=   1.9s
# [CV 4/5; 3/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 4/5; 3/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.717 total time=   1.9s
# [CV 5/5; 3/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 5/5; 3/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.732 total time=   1.6s
# [CV 1/5; 4/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 1/5; 4/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.719 total time=   1.6s
# [CV 2/5; 4/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 2/5; 4/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.6s
# [CV 3/5; 4/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 3/5; 4/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.722 total time=   1.6s
# [CV 4/5; 4/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 4/5; 4/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.717 total time=   1.6s
# [CV 5/5; 4/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 5/5; 4/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.732 total time=   1.6s
# [CV 1/5; 5/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 1/5; 5/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.8s
# [CV 2/5; 5/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 2/5; 5/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.8s
# [CV 3/5; 5/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 3/5; 5/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.721 total time=   1.8s
# [CV 4/5; 5/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 4/5; 5/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.8s
# [CV 5/5; 5/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 5/5; 5/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.733 total time=   1.8s
# [CV 1/5; 6/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 1/5; 6/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.8s
# [CV 2/5; 6/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 2/5; 6/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.9s
# [CV 3/5; 6/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 3/5; 6/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.721 total time=   1.8s
# [CV 4/5; 6/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 4/5; 6/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.717 total time=   1.8s
# [CV 5/5; 6/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 5/5; 6/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.733 total time=   1.8s
# [CV 1/5; 7/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 1/5; 7/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.2s
# [CV 2/5; 7/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 2/5; 7/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.2s
# [CV 3/5; 7/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 3/5; 7/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.721 total time=   2.1s
# [CV 4/5; 7/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 4/5; 7/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.717 total time=   2.2s
# [CV 5/5; 7/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 5/5; 7/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.732 total time=   2.3s
# [CV 1/5; 8/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 1/5; 8/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.719 total time=   2.2s
# [CV 2/5; 8/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 2/5; 8/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.2s
# [CV 3/5; 8/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 3/5; 8/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.721 total time=   2.2s
# [CV 4/5; 8/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 4/5; 8/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.717 total time=   2.2s
# [CV 5/5; 8/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 5/5; 8/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.732 total time=   2.2s
# [CV 1/5; 9/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 1/5; 9/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.719 total time=   2.3s
# [CV 2/5; 9/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 2/5; 9/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.719 total time=   2.5s
# [CV 3/5; 9/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 3/5; 9/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.721 total time=   2.3s
# [CV 4/5; 9/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 4/5; 9/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.717 total time=   2.2s
# [CV 5/5; 9/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 5/5; 9/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.732 total time=   2.3s
# [CV 1/5; 10/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 1/5; 10/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.719 total time=   2.3s
# [CV 2/5; 10/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 2/5; 10/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.719 total time=   2.3s
# [CV 3/5; 10/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 3/5; 10/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.721 total time=   2.3s
# [CV 4/5; 10/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 4/5; 10/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.717 total time=   2.2s
# [CV 5/5; 10/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 5/5; 10/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.732 total time=   2.3s
# [CV 1/5; 11/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 1/5; 11/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.7s
# [CV 2/5; 11/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 2/5; 11/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.7s
# [CV 3/5; 11/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 3/5; 11/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.721 total time=   2.7s
# [CV 4/5; 11/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 4/5; 11/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.717 total time=   2.7s
# [CV 5/5; 11/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 5/5; 11/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.733 total time=   2.7s
# [CV 1/5; 12/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 1/5; 12/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.719 total time=   2.7s
# [CV 2/5; 12/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 2/5; 12/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.7s
# [CV 3/5; 12/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 3/5; 12/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.721 total time=   2.7s
# [CV 4/5; 12/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 4/5; 12/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.717 total time=   2.8s
# [CV 5/5; 12/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 5/5; 12/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.733 total time=   2.7s
# [CV 1/5; 13/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 1/5; 13/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.3s
# [CV 2/5; 13/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 2/5; 13/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.5s
# [CV 3/5; 13/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 3/5; 13/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.720 total time=   1.3s
# [CV 4/5; 13/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 4/5; 13/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.3s
# [CV 5/5; 13/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 5/5; 13/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.732 total time=   1.3s
# [CV 1/5; 14/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 1/5; 14/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.3s
# [CV 2/5; 14/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 2/5; 14/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.3s
# [CV 3/5; 14/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 3/5; 14/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.720 total time=   1.3s
# [CV 4/5; 14/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 4/5; 14/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.3s
# [CV 5/5; 14/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 5/5; 14/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.732 total time=   1.3s
# [CV 1/5; 15/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 1/5; 15/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.718 total time=   1.6s
# [CV 2/5; 15/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 2/5; 15/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.718 total time=   1.6s
# [CV 3/5; 15/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 3/5; 15/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.720 total time=   1.6s
# [CV 4/5; 15/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 4/5; 15/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.718 total time=   1.6s
# [CV 5/5; 15/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 5/5; 15/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.732 total time=   1.6s
# [CV 1/5; 16/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 1/5; 16/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.6s
# [CV 2/5; 16/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 2/5; 16/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.6s
# [CV 3/5; 16/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 3/5; 16/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.720 total time=   1.6s
# [CV 4/5; 16/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 4/5; 16/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.6s
# [CV 5/5; 16/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 5/5; 16/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.732 total time=   1.6s
# [CV 1/5; 17/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 1/5; 17/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.8s
# [CV 2/5; 17/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 2/5; 17/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.8s
# [CV 3/5; 17/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 3/5; 17/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.721 total time=   1.8s
# [CV 4/5; 17/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 4/5; 17/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.8s
# [CV 5/5; 17/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 5/5; 17/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.732 total time=   1.8s
# [CV 1/5; 18/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 1/5; 18/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.8s
# [CV 2/5; 18/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 2/5; 18/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.9s
# [CV 3/5; 18/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 3/5; 18/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.721 total time=   1.9s
# [CV 4/5; 18/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 4/5; 18/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.717 total time=   1.8s
# [CV 5/5; 18/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 5/5; 18/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.732 total time=   1.8s
# [CV 1/5; 19/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 1/5; 19/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.2s
# [CV 2/5; 19/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 2/5; 19/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.2s
# [CV 3/5; 19/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 3/5; 19/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.721 total time=   2.2s
# [CV 4/5; 19/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 4/5; 19/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.2s
# [CV 5/5; 19/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 5/5; 19/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.731 total time=   2.2s
# [CV 1/5; 20/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 1/5; 20/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.719 total time=   2.2s
# [CV 2/5; 20/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 2/5; 20/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.2s
# [CV 3/5; 20/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 3/5; 20/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.721 total time=   2.2s
# [CV 4/5; 20/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 4/5; 20/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.2s
# [CV 5/5; 20/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 5/5; 20/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.731 total time=   2.2s
# [CV 1/5; 21/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 1/5; 21/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.719 total time=   2.3s
# [CV 2/5; 21/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 2/5; 21/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.718 total time=   2.3s
# [CV 3/5; 21/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 3/5; 21/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.721 total time=   2.3s
# [CV 4/5; 21/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 4/5; 21/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.718 total time=   2.3s
# [CV 5/5; 21/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 5/5; 21/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.732 total time=   2.2s
# [CV 1/5; 22/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 1/5; 22/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.719 total time=   2.3s
# [CV 2/5; 22/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 2/5; 22/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.718 total time=   2.3s
# [CV 3/5; 22/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 3/5; 22/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.721 total time=   2.3s
# [CV 4/5; 22/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 4/5; 22/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.718 total time=   2.3s
# [CV 5/5; 22/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 5/5; 22/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.732 total time=   2.3s
# [CV 1/5; 23/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 1/5; 23/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.8s
# [CV 2/5; 23/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 2/5; 23/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.7s
# [CV 3/5; 23/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 3/5; 23/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.721 total time=   2.7s
# [CV 4/5; 23/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 4/5; 23/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.8s
# [CV 5/5; 23/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 5/5; 23/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.731 total time=   2.8s
# [CV 1/5; 24/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 1/5; 24/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.719 total time=   2.8s
# [CV 2/5; 24/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 2/5; 24/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.7s
# [CV 3/5; 24/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 3/5; 24/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.721 total time=   2.8s
# [CV 4/5; 24/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 4/5; 24/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.9s
# [CV 5/5; 24/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 5/5; 24/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.731 total time=   2.8s
# [CV 1/5; 25/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 1/5; 25/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.1s
# [CV 2/5; 25/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 2/5; 25/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.3s
# [CV 3/5; 25/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 3/5; 25/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.720 total time=   1.1s
# [CV 4/5; 25/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 4/5; 25/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.716 total time=   1.1s
# [CV 5/5; 25/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8
# [CV 5/5; 25/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=0.8;, score=0.731 total time=   1.1s
# [CV 1/5; 26/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 1/5; 26/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.1s
# [CV 2/5; 26/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 2/5; 26/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.717 total time=   1.1s
# [CV 3/5; 26/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 3/5; 26/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.720 total time=   1.1s
# [CV 4/5; 26/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 4/5; 26/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.716 total time=   1.1s
# [CV 5/5; 26/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0
# [CV 5/5; 26/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, subsample=1.0;, score=0.731 total time=   1.1s
# [CV 1/5; 27/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 1/5; 27/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.718 total time=   1.2s
# [CV 2/5; 27/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 2/5; 27/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.717 total time=   1.1s
# [CV 3/5; 27/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 3/5; 27/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.720 total time=   1.1s
# [CV 4/5; 27/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 4/5; 27/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.716 total time=   1.1s
# [CV 5/5; 27/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 5/5; 27/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.731 total time=   1.1s
# [CV 1/5; 28/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 1/5; 28/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.1s
# [CV 2/5; 28/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 2/5; 28/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.717 total time=   1.1s
# [CV 3/5; 28/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 3/5; 28/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.720 total time=   1.1s
# [CV 4/5; 28/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 4/5; 28/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.716 total time=   1.1s
# [CV 5/5; 28/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 5/5; 28/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.731 total time=   1.1s
# [CV 1/5; 29/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 1/5; 29/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.719 total time=   1.6s
# [CV 2/5; 29/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 2/5; 29/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.6s
# [CV 3/5; 29/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 3/5; 29/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.721 total time=   1.6s
# [CV 4/5; 29/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 4/5; 29/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.717 total time=   1.5s
# [CV 5/5; 29/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 5/5; 29/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.731 total time=   1.5s
# [CV 1/5; 30/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 1/5; 30/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.719 total time=   1.6s
# [CV 2/5; 30/192] START colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 2/5; 30/192] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_samples=20, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.717 total time=   1.6s
# ...
# [CV 3/5; 183/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 3/5; 183/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.722 total time=   1.4s
# [CV 4/5; 183/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 4/5; 183/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.717 total time=   1.4s
# [CV 5/5; 183/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8
# [CV 5/5; 183/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=0.8;, score=0.732 total time=   1.5s
# [CV 1/5; 184/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 1/5; 184/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.719 total time=   1.6s
# [CV 2/5; 184/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 2/5; 184/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.718 total time=   1.5s
# [CV 3/5; 184/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 3/5; 184/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.722 total time=   1.5s
# [CV 4/5; 184/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 4/5; 184/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.717 total time=   1.5s
# [CV 5/5; 184/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0
# [CV 5/5; 184/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=100, num_leaves=50, subsample=1.0;, score=0.732 total time=   1.3s
# [CV 1/5; 185/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 1/5; 185/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.718 total time=   2.1s
# [CV 2/5; 185/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 2/5; 185/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.718 total time=   1.9s
# [CV 3/5; 185/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 3/5; 185/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.720 total time=   2.1s
# [CV 4/5; 185/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 4/5; 185/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.718 total time=   2.1s
# [CV 5/5; 185/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8
# [CV 5/5; 185/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=0.8;, score=0.732 total time=   2.0s
# [CV 1/5; 186/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 1/5; 186/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.718 total time=   2.1s
# [CV 2/5; 186/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 2/5; 186/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.718 total time=   1.9s
# [CV 3/5; 186/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 3/5; 186/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.720 total time=   2.0s
# [CV 4/5; 186/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 4/5; 186/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.718 total time=   2.0s
# [CV 5/5; 186/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0
# [CV 5/5; 186/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=31, subsample=1.0;, score=0.732 total time=   2.1s
# [CV 1/5; 187/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 1/5; 187/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.719 total time=   1.9s
# [CV 2/5; 187/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 2/5; 187/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.0s
# [CV 3/5; 187/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 3/5; 187/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.720 total time=   2.2s
# [CV 4/5; 187/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 4/5; 187/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.718 total time=   2.3s
# [CV 5/5; 187/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8
# [CV 5/5; 187/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=0.8;, score=0.731 total time=   2.3s
# [CV 1/5; 188/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 1/5; 188/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.719 total time=   2.0s
# [CV 2/5; 188/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 2/5; 188/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.719 total time=   3.2s
# [CV 3/5; 188/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 3/5; 188/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.720 total time=   2.2s
# [CV 4/5; 188/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 4/5; 188/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.718 total time=   2.3s
# [CV 5/5; 188/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0
# [CV 5/5; 188/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=150, num_leaves=50, subsample=1.0;, score=0.731 total time=   2.4s
# [CV 1/5; 189/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 1/5; 189/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.719 total time=   2.9s
# [CV 2/5; 189/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 2/5; 189/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.719 total time=   3.5s
# [CV 3/5; 189/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 3/5; 189/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.720 total time=   3.0s
# [CV 4/5; 189/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 4/5; 189/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.718 total time=   2.5s
# [CV 5/5; 189/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8
# [CV 5/5; 189/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=0.8;, score=0.731 total time=   2.7s
# [CV 1/5; 190/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 1/5; 190/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.719 total time=   2.7s
# [CV 2/5; 190/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 2/5; 190/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.719 total time=   2.7s
# [CV 3/5; 190/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 3/5; 190/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.720 total time=   2.9s
# [CV 4/5; 190/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 4/5; 190/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.718 total time=   2.8s
# [CV 5/5; 190/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0
# [CV 5/5; 190/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=31, subsample=1.0;, score=0.731 total time=   2.9s
# [CV 1/5; 191/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 1/5; 191/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.719 total time=   3.0s
# [CV 2/5; 191/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 2/5; 191/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.719 total time=   3.0s
# [CV 3/5; 191/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 3/5; 191/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.719 total time=   2.8s
# [CV 4/5; 191/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 4/5; 191/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.717 total time=   2.9s
# [CV 5/5; 191/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8
# [CV 5/5; 191/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=0.8;, score=0.731 total time=   3.0s
# [CV 1/5; 192/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 1/5; 192/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.719 total time=   3.1s
# [CV 2/5; 192/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 2/5; 192/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.719 total time=   3.1s
# [CV 3/5; 192/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 3/5; 192/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.719 total time=   3.0s
# [CV 4/5; 192/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 4/5; 192/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.717 total time=   2.6s
# [CV 5/5; 192/192] START colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0
# [CV 5/5; 192/192] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=50, subsample=1.0;, score=0.731 total time=   2.7s
# /opt/anaconda3/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best score: 0.7218224201696597
# Best parameters set:
# 	colsample_bytree: 0.8
# 	learning_rate: 0.1
# 	max_depth: -1
# 	min_child_samples: 20
# 	n_estimators: 100
# 	num_leaves: 50
# 	subsample: 0.8

# %%
tuned_lgb = lgb.LGBMClassifier(
    colsample_bytree=0.8,
    learning_rate=0.1,
    max_depth=-1,
    min_child_samples=20,
    n_estimators=100,
    num_leaves=50,
    subsample=0.8,
    n_jobs=-1,
    verbose=-1
)

# %%
train_model(train_norm_pca_df, 5, train_norm_selected_features, tuned_lgb)
# Out:
# Fold 0, Accuracy: 0.7339
# Fold 1, Accuracy: 0.7263
# Fold 2, Accuracy: 0.7284
# Fold 3, Accuracy: 0.7261
# Fold 4, Accuracy: 0.7259
# Mean Accuracy: 0.7281
# 0.7281062804504673

# %%
train_model(train_norm_pca_df, 5, train_pca_features, tuned_lgb)
# Out:
# Fold 0, Accuracy: 0.7254
# Fold 1, Accuracy: 0.7199
# Fold 2, Accuracy: 0.7200
# Fold 3, Accuracy: 0.7187
# Fold 4, Accuracy: 0.7191
# Mean Accuracy: 0.7206
# 0.7206091424615958

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
# initialize Random Forest model
rf = ensemble.RandomForestClassifier(
    n_jobs=-1
    )

# %%
train_model(train_norm_pca_df, 5, train_features, rf)
# Out:
# Fold 0, Accuracy: 0.7306
# Fold 1, Accuracy: 0.7256
# Fold 2, Accuracy: 0.7282
# Fold 3, Accuracy: 0.7235
# Fold 4, Accuracy: 0.7234
# Mean Accuracy: 0.7263
# 0.726269268656319

# %%
train_model(train_norm_pca_df, 5, train_norm_selected_features, rf)
# Out:
# Fold 0, Accuracy: 0.7264
# Fold 1, Accuracy: 0.7207
# Fold 2, Accuracy: 0.7211
# Fold 3, Accuracy: 0.7191
# Fold 4, Accuracy: 0.7191
# Mean Accuracy: 0.7213
# 0.7212853757887171

# %%
# define a grid of parameters
param_grid = {
    "n_estimators": [100, 200, 250, 300, 400, 500],
    "max_depth": [1, 2, 5, 7, 11, 15],
    "criterion": ["gini", "entropy"]
}

# %%
# initialize grid search
# we use f1_weighted as our metric
# cv=5 means that we are using 5 fold cv
model = model_selection.GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring="f1_weighted",
    verbose=10,
    n_jobs=1,
    cv=5
)

# %%
# fit model on training data
model.fit(X, y)

# get best score
print(f"Best score: {model.best_score_}")

# get best params
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.371 total time=   0.5s
# [CV 2/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.326 total time=   0.5s
# [CV 3/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.380 total time=   0.5s
# [CV 4/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.380 total time=   0.5s
# [CV 5/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.379 total time=   0.5s
# [CV 1/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.372 total time=   1.0s
# [CV 2/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.380 total time=   1.0s
# [CV 3/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.380 total time=   1.0s
# [CV 4/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.380 total time=   0.9s
# [CV 5/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.379 total time=   0.9s
# [CV 1/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 1/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.379 total time=   1.2s
# [CV 2/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 2/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.380 total time=   1.2s
# [CV 3/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 3/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.380 total time=   1.1s
# [CV 4/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 4/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.380 total time=   1.1s
# [CV 5/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 5/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.379 total time=   1.1s
# [CV 1/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.379 total time=   1.4s
# [CV 2/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.380 total time=   1.4s
# [CV 3/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.380 total time=   1.4s
# [CV 4/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.380 total time=   1.4s
# [CV 5/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.379 total time=   1.3s
# [CV 1/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.379 total time=   1.8s
# [CV 2/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.380 total time=   1.8s
# [CV 3/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.380 total time=   1.8s
# [CV 4/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.380 total time=   1.9s
# [CV 5/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.379 total time=   1.8s
# [CV 1/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 1/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.379 total time=   2.3s
# [CV 2/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 2/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.380 total time=   2.3s
# [CV 3/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 3/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.380 total time=   2.3s
# [CV 4/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 4/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.380 total time=   2.3s
# [CV 5/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 5/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.379 total time=   2.3s
# [CV 1/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 1/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.562 total time=   0.7s
# [CV 2/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 2/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.547 total time=   0.7s
# [CV 3/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 3/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.513 total time=   0.7s
# [CV 4/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 4/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.560 total time=   0.7s
# [CV 5/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 5/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.539 total time=   0.7s
# [CV 1/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 1/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.563 total time=   1.3s
# [CV 2/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 2/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.539 total time=   1.3s
# [CV 3/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 3/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.554 total time=   1.3s
# [CV 4/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 4/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.540 total time=   1.3s
# [CV 5/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 5/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.581 total time=   1.3s
# [CV 1/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 1/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.533 total time=   1.6s
# [CV 2/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 2/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.562 total time=   1.6s
# [CV 3/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 3/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.555 total time=   1.6s
# [CV 4/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 4/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.554 total time=   1.6s
# [CV 5/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 5/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.531 total time=   1.6s
# [CV 1/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 1/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.525 total time=   1.9s
# [CV 2/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 2/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.562 total time=   1.9s
# [CV 3/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 3/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.562 total time=   1.9s
# [CV 4/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 4/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.532 total time=   1.9s
# [CV 5/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 5/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.553 total time=   1.9s
# [CV 1/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 1/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.554 total time=   2.6s
# [CV 2/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 2/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.545 total time=   2.6s
# [CV 3/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 3/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.559 total time=   2.6s
# [CV 4/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 4/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.544 total time=   2.5s
# [CV 5/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 5/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.538 total time=   2.6s
# [CV 1/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 1/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.558 total time=   3.3s
# [CV 2/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 2/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.533 total time=   3.2s
# [CV 3/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 3/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.564 total time=   3.2s
# [CV 4/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 4/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.543 total time=   3.2s
# [CV 5/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 5/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.546 total time=   3.3s
# [CV 1/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 1/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.700 total time=   1.3s
# [CV 2/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 2/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.695 total time=   1.3s
# [CV 3/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 3/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.702 total time=   1.3s
# [CV 4/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 4/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.699 total time=   1.3s
# [CV 5/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 5/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.709 total time=   1.3s
# [CV 1/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.701 total time=   2.6s
# [CV 2/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.698 total time=   2.6s
# [CV 3/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.701 total time=   2.5s
# [CV 4/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.697 total time=   2.5s
# [CV 5/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.708 total time=   2.5s
# [CV 1/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 1/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.700 total time=   3.2s
# [CV 2/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 2/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.696 total time=   3.2s
# [CV 3/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 3/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.702 total time=   3.1s
# [CV 4/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 4/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.697 total time=   3.3s
# [CV 5/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 5/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.707 total time=   3.2s
# [CV 1/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.702 total time=   3.8s
# [CV 2/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.695 total time=   3.8s
# [CV 3/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.700 total time=   3.8s
# [CV 4/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.698 total time=   3.8s
# [CV 5/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.710 total time=   3.8s
# [CV 1/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.701 total time=   5.1s
# [CV 2/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.696 total time=   5.1s
# [CV 3/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.701 total time=   5.0s
# [CV 4/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.697 total time=   5.1s
# [CV 5/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.706 total time=   5.1s
# [CV 1/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 1/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.701 total time=   6.3s
# [CV 2/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 2/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.696 total time=   6.4s
# [CV 3/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 3/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.702 total time=   6.4s
# [CV 4/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 4/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.698 total time=   6.3s
# [CV 5/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 5/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.709 total time=   6.6s
# [CV 1/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.708 total time=   1.8s
# [CV 2/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.704 total time=   1.8s
# [CV 3/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.708 total time=   1.8s
# [CV 4/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.708 total time=   1.8s
# [CV 5/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.718 total time=   1.8s
# [CV 1/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.708 total time=   3.5s
# [CV 2/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.705 total time=   3.5s
# [CV 3/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.710 total time=   3.6s
# [CV 4/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.707 total time=   3.6s
# [CV 5/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.718 total time=   3.6s
# [CV 1/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 1/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.708 total time=   4.7s
# [CV 2/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 2/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.704 total time=   4.6s
# [CV 3/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 3/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.709 total time=   4.7s
# [CV 4/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 4/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.707 total time=   4.7s
# [CV 5/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 5/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.717 total time=   4.7s
# [CV 1/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.708 total time=   5.8s
# [CV 2/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.704 total time=   5.8s
# [CV 3/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.709 total time=   5.9s
# [CV 4/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.706 total time=   5.9s
# [CV 5/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.717 total time=   5.9s
# [CV 1/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.708 total time=   7.9s
# [CV 2/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.705 total time=   8.0s
# [CV 3/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.709 total time=   8.0s
# [CV 4/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.707 total time=   7.9s
# [CV 5/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.717 total time=   8.0s
# [CV 1/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 1/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.707 total time=  10.1s
# [CV 2/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 2/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.704 total time=  10.0s
# [CV 3/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 3/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.708 total time=   9.9s
# [CV 4/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 4/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.707 total time=   9.8s
# [CV 5/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 5/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.717 total time=   9.8s
# [CV 1/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 1/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.715 total time=   3.1s
# [CV 2/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 2/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.712 total time=   3.1s
# [CV 3/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 3/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.715 total time=   2.9s
# [CV 4/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 4/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.713 total time=   2.9s
# [CV 5/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 5/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.724 total time=   2.9s
# [CV 1/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 1/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.715 total time=   5.6s
# [CV 2/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 2/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.712 total time=   5.7s
# [CV 3/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 3/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.715 total time=   5.6s
# [CV 4/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 4/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.713 total time=   5.6s
# [CV 5/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 5/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.725 total time=   5.6s
# [CV 1/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 1/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.714 total time=   7.0s
# [CV 2/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 2/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.712 total time=   7.0s
# [CV 3/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 3/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.715 total time=   7.0s
# [CV 4/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 4/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.713 total time=   7.0s
# [CV 5/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 5/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.725 total time=   7.0s
# [CV 1/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 1/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.715 total time=   8.4s
# [CV 2/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 2/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.713 total time=   8.4s
# [CV 3/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 3/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.715 total time=   8.5s
# [CV 4/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 4/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.712 total time=   8.4s
# [CV 5/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 5/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.725 total time=   8.5s
# [CV 1/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 1/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.715 total time=  11.2s
# [CV 2/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 2/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.712 total time=  11.3s
# [CV 3/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 3/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.715 total time=  11.3s
# [CV 4/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 4/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.713 total time=  11.5s
# [CV 5/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 5/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.726 total time=  11.4s
# [CV 1/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 1/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.715 total time=  14.3s
# [CV 2/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 2/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.712 total time=  14.4s
# [CV 3/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 3/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.716 total time=  14.3s
# [CV 4/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 4/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.713 total time=  14.4s
# [CV 5/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 5/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.725 total time=  14.4s
# [CV 1/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 1/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.716 total time=   4.0s
# [CV 2/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 2/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.715 total time=   4.0s
# [CV 3/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 3/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.718 total time=   3.9s
# [CV 4/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 4/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.714 total time=   3.9s
# [CV 5/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 5/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.728 total time=   3.9s
# [CV 1/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 1/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.716 total time=   7.6s
# [CV 2/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 2/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.715 total time=   7.6s
# [CV 3/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 3/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.719 total time=   7.5s
# [CV 4/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 4/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.715 total time=   7.5s
# [CV 5/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 5/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.728 total time=   7.7s
# [CV 1/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 1/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.716 total time=   9.7s
# [CV 2/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 2/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.716 total time=  10.1s
# [CV 3/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 3/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.719 total time=  10.3s
# [CV 4/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 4/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.715 total time=  10.2s
# [CV 5/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 5/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.728 total time=  10.3s
# [CV 1/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 1/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.716 total time=  12.2s
# [CV 2/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 2/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.715 total time=  12.0s
# [CV 3/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 3/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.719 total time=  11.5s
# [CV 4/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 4/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.715 total time=  11.0s
# [CV 5/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 5/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.728 total time=  10.4s
# [CV 1/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 1/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.716 total time=  13.2s
# [CV 2/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 2/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.715 total time=  12.8s
# [CV 3/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 3/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.719 total time=  12.4s
# [CV 4/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 4/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.715 total time=  12.3s
# [CV 5/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 5/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.728 total time=  12.4s
# [CV 1/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 1/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.716 total time=  15.4s
# [CV 2/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 2/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.716 total time=  15.5s
# [CV 3/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 3/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.719 total time=  16.2s
# [CV 4/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 4/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.715 total time=  15.5s
# [CV 5/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 5/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.728 total time=  15.6s
# [CV 1/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.379 total time=   0.5s
# [CV 2/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.380 total time=   0.5s
# [CV 3/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.380 total time=   0.5s
# [CV 4/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.380 total time=   0.5s
# [CV 5/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.379 total time=   0.5s
# [CV 1/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.379 total time=   1.1s
# [CV 2/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.380 total time=   1.1s
# [CV 3/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.380 total time=   1.0s
# [CV 4/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.380 total time=   1.1s
# [CV 5/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.379 total time=   1.1s
# [CV 1/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 1/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.379 total time=   1.3s
# [CV 2/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 2/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.380 total time=   1.3s
# [CV 3/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 3/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.380 total time=   1.3s
# [CV 4/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 4/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.380 total time=   1.3s
# [CV 5/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 5/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.379 total time=   1.3s
# [CV 1/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.379 total time=   1.6s
# [CV 2/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.380 total time=   1.6s
# [CV 3/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.380 total time=   1.5s
# [CV 4/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.380 total time=   1.5s
# [CV 5/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.379 total time=   1.5s
# [CV 1/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.379 total time=   2.0s
# [CV 2/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.380 total time=   2.1s
# [CV 3/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.380 total time=   2.1s
# [CV 4/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.380 total time=   2.0s
# [CV 5/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.379 total time=   2.0s
# [CV 1/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 1/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.379 total time=   2.6s
# [CV 2/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 2/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.380 total time=   2.6s
# [CV 3/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 3/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.380 total time=   2.5s
# [CV 4/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 4/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.380 total time=   2.5s
# [CV 5/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 5/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.379 total time=   2.6s
# [CV 1/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 1/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.526 total time=   0.7s
# [CV 2/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 2/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.543 total time=   0.7s
# [CV 3/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 3/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.516 total time=   0.7s
# [CV 4/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 4/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.436 total time=   0.7s
# [CV 5/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 5/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.496 total time=   0.7s
# [CV 1/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 1/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.516 total time=   1.4s
# [CV 2/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 2/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.516 total time=   1.4s
# [CV 3/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 3/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.515 total time=   1.4s
# [CV 4/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 4/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.528 total time=   1.4s
# [CV 5/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 5/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.519 total time=   1.4s
# [CV 1/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 1/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.513 total time=   1.8s
# [CV 2/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 2/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.513 total time=   1.7s
# [CV 3/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 3/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.524 total time=   1.7s
# [CV 4/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 4/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.525 total time=   1.7s
# [CV 5/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 5/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.515 total time=   1.7s
# [CV 1/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 1/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.516 total time=   2.1s
# [CV 2/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 2/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.521 total time=   2.1s
# [CV 3/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 3/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.518 total time=   2.0s
# [CV 4/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 4/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.515 total time=   2.1s
# [CV 5/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 5/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.508 total time=   2.0s
# [CV 1/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 1/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.515 total time=   2.7s
# [CV 2/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 2/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.509 total time=   2.7s
# [CV 3/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 3/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.518 total time=   2.7s
# [CV 4/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 4/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.518 total time=   2.7s
# [CV 5/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 5/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.520 total time=   2.7s
# [CV 1/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 1/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.524 total time=   3.4s
# [CV 2/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 2/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.516 total time=   3.4s
# [CV 3/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 3/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.504 total time=   3.4s
# [CV 4/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 4/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.521 total time=   3.4s
# [CV 5/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 5/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.522 total time=   3.4s
# [CV 1/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.699 total time=   1.3s
# [CV 2/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.696 total time=   1.3s
# [CV 3/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.698 total time=   1.3s
# [CV 4/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.697 total time=   1.3s
# [CV 5/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.703 total time=   1.3s
# [CV 1/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.698 total time=   2.6s
# [CV 2/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.696 total time=   2.6s
# [CV 3/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.702 total time=   2.6s
# [CV 4/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.697 total time=   2.6s
# [CV 5/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.706 total time=   2.6s
# [CV 1/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 1/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.700 total time=   3.3s
# [CV 2/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 2/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.696 total time=   3.2s
# [CV 3/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 3/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.702 total time=   3.2s
# [CV 4/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 4/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.696 total time=   3.3s
# [CV 5/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 5/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.706 total time=   3.2s
# [CV 1/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.699 total time=   3.9s
# [CV 2/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.696 total time=   3.9s
# [CV 3/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.702 total time=   3.8s
# [CV 4/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.698 total time=   3.9s
# [CV 5/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.709 total time=   3.8s
# [CV 1/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.699 total time=   5.2s
# [CV 2/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.695 total time=   5.1s
# [CV 3/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.702 total time=   5.1s
# [CV 4/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.697 total time=   5.1s
# [CV 5/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# ...
# [CV 5/5; 55/72] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 55/72] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.717 total time=   1.7s
# [CV 1/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.708 total time=   3.4s
# [CV 2/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.705 total time=   3.4s
# [CV 3/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.709 total time=   3.4s
# [CV 4/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.706 total time=   3.4s
# [CV 5/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.717 total time=   3.4s
# [CV 1/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 1/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.708 total time=   4.2s
# [CV 2/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 2/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.704 total time=   4.2s
# [CV 3/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 3/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.709 total time=   4.2s
# [CV 4/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 4/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.706 total time=   4.2s
# [CV 5/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 5/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.717 total time=   4.2s
# [CV 1/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.709 total time=   5.1s
# [CV 2/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.705 total time=   5.0s
# [CV 3/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.709 total time=   5.0s
# [CV 4/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.707 total time=   5.0s
# [CV 5/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.717 total time=   5.0s
# [CV 1/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.709 total time=   6.7s
# [CV 2/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.705 total time=   6.7s
# [CV 3/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.709 total time=   6.7s
# [CV 4/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.707 total time=   6.7s
# [CV 5/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.717 total time=   6.7s
# [CV 1/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 1/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.709 total time=   8.4s
# [CV 2/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 2/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.705 total time=   8.4s
# [CV 3/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 3/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.709 total time=   8.3s
# [CV 4/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 4/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.706 total time=   8.3s
# [CV 5/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 5/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.716 total time=   8.3s
# [CV 1/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 1/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.715 total time=   2.6s
# [CV 2/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 2/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.711 total time=   2.6s
# [CV 3/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 3/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.715 total time=   2.6s
# [CV 4/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 4/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.712 total time=   2.6s
# [CV 5/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 5/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.724 total time=   2.6s
# [CV 1/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 1/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.715 total time=   5.0s
# [CV 2/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 2/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.713 total time=   5.1s
# [CV 3/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 3/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.715 total time=   5.1s
# [CV 4/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 4/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.713 total time=   5.0s
# [CV 5/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 5/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.725 total time=   5.0s
# [CV 1/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 1/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.715 total time=   6.3s
# [CV 2/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 2/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.712 total time=   6.3s
# [CV 3/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 3/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.715 total time=   6.3s
# [CV 4/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 4/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.712 total time=   6.3s
# [CV 5/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 5/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.725 total time=   6.3s
# [CV 1/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 1/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.715 total time=   7.5s
# [CV 2/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 2/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.712 total time=   7.6s
# [CV 3/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 3/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.715 total time=   7.6s
# [CV 4/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 4/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.712 total time=   7.6s
# [CV 5/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 5/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.725 total time=   7.5s
# [CV 1/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 1/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.715 total time=  10.0s
# [CV 2/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 2/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.712 total time=  10.1s
# [CV 3/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 3/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.715 total time=  10.0s
# [CV 4/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 4/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.712 total time=  10.1s
# [CV 5/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 5/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.724 total time=  10.0s
# [CV 1/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 1/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.715 total time=  12.5s
# [CV 2/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 2/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.712 total time=  12.6s
# [CV 3/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 3/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.715 total time=  12.5s
# [CV 4/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 4/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.713 total time=  12.4s
# [CV 5/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 5/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.725 total time=  12.5s
# [CV 1/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 1/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.716 total time=   3.6s
# [CV 2/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 2/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.714 total time=   3.5s
# [CV 3/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 3/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.716 total time=   3.5s
# [CV 4/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 4/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.714 total time=   3.5s
# [CV 5/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 5/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.728 total time=   3.5s
# [CV 1/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 1/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.716 total time=   6.9s
# [CV 2/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 2/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.715 total time=   6.9s
# [CV 3/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 3/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.717 total time=   6.9s
# [CV 4/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 4/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.714 total time=   6.9s
# [CV 5/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 5/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.728 total time=   6.9s
# [CV 1/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 1/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.716 total time=   8.6s
# [CV 2/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 2/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.715 total time=   8.6s
# [CV 3/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 3/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.719 total time=   8.7s
# [CV 4/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 4/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.714 total time=   8.6s
# [CV 5/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 5/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.728 total time=   8.6s
# [CV 1/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 1/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.716 total time=  10.4s
# [CV 2/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 2/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.715 total time=  10.6s
# [CV 3/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 3/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.718 total time=  10.4s
# [CV 4/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 4/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.715 total time=  12.1s
# [CV 5/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 5/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.728 total time=  11.4s
# [CV 1/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 1/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.717 total time=  15.1s
# [CV 2/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 2/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.715 total time=  15.6s
# [CV 3/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 3/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.719 total time=  15.8s
# [CV 4/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 4/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.714 total time=  14.9s
# [CV 5/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 5/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.727 total time=  14.6s
# [CV 1/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 1/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.716 total time=  19.1s
# [CV 2/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 2/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.716 total time=  19.2s
# [CV 3/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 3/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.719 total time=  17.6s
# [CV 4/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 4/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.715 total time=  19.2s
# [CV 5/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 5/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.728 total time=  18.9s
# Best score: 0.7189074251368996
# Best parameters set:
# 	criterion: gini
# 	max_depth: 15
# 	n_estimators: 500

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Extract results from GridSearchCV
results = model.cv_results_
mean_test_scores = results['mean_test_score']
params = results['params']

# Prepare data for plotting
criteria = ["gini", "entropy"]
fig = plt.figure(figsize=(20, 10))

for i, criterion in enumerate(criteria):
    # Filter results for the current criterion
    filtered_results = [
        (param['n_estimators'], param['max_depth'], mean_test_scores[idx])
        for idx, param in enumerate(params)
        if param['criterion'] == criterion
    ]
    
    # Convert to numpy arrays for plotting
    n_estimators = np.array([x[0] for x in filtered_results])
    max_depth = np.array([x[1] for x in filtered_results])
    scores = np.array([x[2] for x in filtered_results])
    
    # Create a grid for n_estimators and max_depth
    n_estimators_unique = np.unique(n_estimators)
    max_depth_unique = np.unique(max_depth)
    X, Y = np.meshgrid(n_estimators_unique, max_depth_unique)
    Z = np.zeros_like(X, dtype=float)
    
    # Fill Z with corresponding scores
    for x, y, z in zip(n_estimators, max_depth, scores):
        Z[np.where(max_depth_unique == y)[0][0], np.where(n_estimators_unique == x)[0][0]] = z
    
    # Plot 3D surface
    ax = fig.add_subplot(1, 2, i + 1, projection='3d')
    surf = ax.plot_surface(X, Y, Z, cmap='Blues', edgecolor='k', alpha=0.8)
    ax.set_title(f"Criterion: {criterion}")
    ax.set_xlabel("n_estimators")
    ax.set_ylabel("max_depth")
    ax.set_zlabel("F1 Score")

plt.tight_layout()
plt.show()

# %%
# initialize tuned Random Forest model
tuned_rf = ensemble.RandomForestClassifier(
    criterion='gini',
    max_depth=15,
    n_estimators=500,
    n_jobs=-1
)

# %%
train_model(train_norm_pca_df, 5, train_norm_selected_features, tuned_rf)
# Out:
# Fold 0, Accuracy: 0.7315
# Fold 1, Accuracy: 0.7252
# Fold 2, Accuracy: 0.7263
# Fold 3, Accuracy: 0.7236
# Fold 4, Accuracy: 0.7232
# Mean Accuracy: 0.7260
# 0.7259604376880274

# %%
train_model(train_norm_pca_df, 5, train_pca_features, tuned_rf)
# Out:
# Fold 0, Accuracy: 0.7246
# Fold 1, Accuracy: 0.7176
# Fold 2, Accuracy: 0.7182
# Fold 3, Accuracy: 0.7164
# Fold 4, Accuracy: 0.7177
# Mean Accuracy: 0.7189
# 0.7189105721359922

# %% [markdown]
# # Using plays from the 2022-23 and 2023-24 seasons to measure whether players are indeed traded based on performance

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

def filter_data_by_year(df, year):
    return df[df['GAME_DATE'].dt.year == year]

def preprocess_data(df):
    df = df.dropna(subset=["MIN"]).copy()
    df.drop(columns=["START_POSITION", "MIN"], inplace=True)
    return df

def normalize_features(df, feature_columns):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df[feature_columns].values)
    normalized_columns = [feat + '_n' for feat in feature_columns]
    norm_df = pd.concat([df.reset_index(drop=True), pd.DataFrame(data=scaled_data, columns=normalized_columns)], axis=1)
    return norm_df, normalized_columns

def apply_pca(df, normalized_columns, n_components=7):
    pca = PCA(n_components=n_components)
    pca_data = pca.fit_transform(df[normalized_columns].values)
    pca_columns = [f'pca_{i+1}' for i in range(n_components)]
    pca_df = pd.concat([df.reset_index(drop=True), pd.DataFrame(data=pca_data, columns=pca_columns)], axis=1)
    return pca_df, pca_columns

def add_cluster_predictions(df, pca_columns, model):
    X = df[pca_columns].values
    df['pred_cluster'] = model.predict(X)
    return df

def process_player_data(player_name, trade_date, df):
    player_df = df[(df.PLAYER_NAME == player_name) & (df.GAME_DATE < trade_date)].copy()
    cluster_counts = player_df['pred_cluster'].value_counts(normalize=True) * 100
    return cluster_counts

def process_trades(trade_data, processed_df, expected_clusters, trade_year):
    trade_data['DATE_OF_SIGN'] = pd.to_datetime(trade_data['DATE_OF_SIGN'])
    filtered_trades = trade_data[trade_data['DATE_OF_SIGN'].dt.year == trade_year]

    correct_trades = 0
    total_trades = 0

    for index, trade in filtered_trades.iterrows():
        print(f"\nProcessing trade for {trade['TRADED']} ({trade['POSITION']})...")
        candidate_percentages = []

        for player in trade['CANDIDATES'].split(','):
            player = player.strip()
            print(f"  Processing data for {player}...")
            cluster_percentages = process_player_data(player, trade['DATE_OF_SIGN'], processed_df)
            candidate_percentages.append((player, cluster_percentages))
            print(f"    Cluster percentages for {player}:\n{cluster_percentages}")

        target_player_percentages = process_player_data(trade['TRADED'], trade['DATE_OF_SIGN'], processed_df)
        print(f"    Target player {trade['TRADED']} cluster percentages:\n{target_player_percentages}")
        
        # Combine all candidates (including traded player) and sort by the expected cluster percentage
        expected_cluster = expected_clusters.get(trade['POSITION'], None)
        if expected_cluster is not None:
            all_candidates = candidate_percentages + [(trade['TRADED'], target_player_percentages)]
            sorted_candidates = sorted(
                all_candidates,
                key=lambda x: x[1].get(expected_cluster, 0),
                reverse=True
            )
            
            # Check if the traded player is in the top 3
            total_trades += 1
            top_candidates = sorted_candidates[:3]
            if any(player == trade['TRADED'] for player, _ in top_candidates):
                correct_trades += 1
                print(f"    The traded player {trade['TRADED']} is in the top 3 candidates for the expected cluster ({expected_cluster}).")
            else:
                print(f"    The traded player {trade['TRADED']} is NOT in the top 3 candidates for the expected cluster ({expected_cluster}).")

    if total_trades > 0:
        accuracy = (correct_trades / total_trades) * 100
        print(f"\nOverall accuracy for trades in {trade_year}: {accuracy:.2f}%")
    else:
        print(f"\nNo trades found for the year {trade_year}.")

def main_pipeline(df, year, model, trade_data_path, expected_clusters, trade_year):
    df_year = filter_data_by_year(df, year)
    df_year.to_csv(f'nba_data_{year}.csv', index=False)
    print(f"{year} stats have been saved to 'nba_data_{year}.csv'.")

    df_year = preprocess_data(df_year)

    feature_columns = [
        col for col in df_year.columns
        if col not in (
            "GAME_ID", "TEAM_ID", "TEAM_ABBREVIATION", "TEAM_CITY",
            "PLAYER_ID", "PLAYER_NAME", "NICKNAME", "GAME_DATE"
        )
    ]

    df_year_norm, normalized_columns = normalize_features(df_year, feature_columns)
    df_year_pca, pca_columns = apply_pca(df_year_norm, normalized_columns)
    processed_df = add_cluster_predictions(df_year_pca, pca_columns, model)

    trade_data = pd.read_csv(trade_data_path)
    process_trades(trade_data, processed_df, expected_clusters, trade_year)

# Example usage:
# Assuming `df_2022_2024` is the dataset and `tuned_logres` is the trained model.
expected_clusters = {'C': 1, 'F': 3, 'G': 3}  # Example expected clusters by position
main_pipeline(df_2022_2024, 2022, tuned_lgb, 'NBA_TRADE.csv', expected_clusters, 2023)
# Out:
# 2022 stats have been saved to 'nba_data_2022.csv'.
#
# Processing trade for Rui Hachimura (F)...
#   Processing data for Jerami Grant...
#     Cluster percentages for Jerami Grant:
# pred_cluster
# 3    48.333333
# 1    35.000000
# 0    16.666667
# Name: proportion, dtype: float64
#   Processing data for Rui Hachimura...
#     Cluster percentages for Rui Hachimura:
# pred_cluster
# 0    56.716418
# 1    41.791045
# 3     1.492537
# Name: proportion, dtype: float64
#     Target player Rui Hachimura cluster percentages:
# pred_cluster
# 0    56.716418
# 1    41.791045
# 3     1.492537
# Name: proportion, dtype: float64
#     The traded player Rui Hachimura is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Kendrick Nunn (G)...
#   Processing data for Jaden Ivey...
#     Cluster percentages for Jaden Ivey:
# pred_cluster
# 3    58.974359
# 0    23.076923
# 1    17.948718
# Name: proportion, dtype: float64
#   Processing data for Shai Gilgeous-Alexander...
#     Cluster percentages for Shai Gilgeous-Alexander:
# pred_cluster
# 3    91.379310
# 1     6.896552
# 0     1.724138
# Name: proportion, dtype: float64
#   Processing data for Dejounte Murray...
#     Cluster percentages for Dejounte Murray:
# pred_cluster
# 3    78.082192
# 1    16.438356
# 0     5.479452
# Name: proportion, dtype: float64
#   Processing data for Kendrick Nunn...
#     Cluster percentages for Kendrick Nunn:
# pred_cluster
# 0    57.575758
# 2    30.303030
# 1     9.090909
# 3     3.030303
# Name: proportion, dtype: float64
#     Target player Kendrick Nunn cluster percentages:
# pred_cluster
# 0    57.575758
# 2    30.303030
# 1     9.090909
# 3     3.030303
# Name: proportion, dtype: float64
#     The traded player Kendrick Nunn is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Kyrie Irving (G)...
#   Processing data for Fred VanVleet...
#     Cluster percentages for Fred VanVleet:
# pred_cluster
# 3    76.712329
# 1    13.698630
# 0     9.589041
# Name: proportion, dtype: float64
#   Processing data for Dejounte Murray...
#     Cluster percentages for Dejounte Murray:
# pred_cluster
# 3    78.082192
# 1    16.438356
# 0     5.479452
# Name: proportion, dtype: float64
#   Processing data for Jaden Ivey...
#     Cluster percentages for Jaden Ivey:
# pred_cluster
# 3    58.974359
# 0    23.076923
# 1    17.948718
# Name: proportion, dtype: float64
#   Processing data for Collin Sexton...
#     Cluster percentages for Collin Sexton:
# pred_cluster
# 0    55.555556
# 3    30.555556
# 1    13.888889
# Name: proportion, dtype: float64
#   Processing data for Kyrie Irving...
#     Cluster percentages for Kyrie Irving:
# pred_cluster
# 3    76.190476
# 1    19.047619
# 0     4.761905
# Name: proportion, dtype: float64
#     Target player Kyrie Irving cluster percentages:
# pred_cluster
# 3    76.190476
# 1    19.047619
# 0     4.761905
# Name: proportion, dtype: float64
#     The traded player Kyrie Irving is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Markieff Morris (C)...
#   Processing data for Mason Plumlee...
#     Cluster percentages for Mason Plumlee:
# pred_cluster
# 0    57.303371
# 1    41.573034
# 3     1.123596
# Name: proportion, dtype: float64
#   Processing data for Jakob Pöltl...
#     Cluster percentages for Jakob Pöltl:
# pred_cluster
# 1    74.324324
# 0    22.972973
# 3     2.702703
# Name: proportion, dtype: float64
#   Processing data for Bismack Biyombo...
#     Cluster percentages for Bismack Biyombo:
# pred_cluster
# 0    49.350649
# 2    31.168831
# 1    19.480519
# Name: proportion, dtype: float64
#   Processing data for Nerlens Noel...
#     Cluster percentages for Nerlens Noel:
# pred_cluster
# 0    53.333333
# 2    26.666667
# 1    20.000000
# Name: proportion, dtype: float64
#   Processing data for Markieff Morris...
#     Cluster percentages for Markieff Morris:
# pred_cluster
# 0    77.419355
# 2    16.129032
# 1     6.451613
# Name: proportion, dtype: float64
#     Target player Markieff Morris cluster percentages:
# pred_cluster
# 0    77.419355
# 2    16.129032
# 1     6.451613
# Name: proportion, dtype: float64
#     The traded player Markieff Morris is NOT in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Spencer Dinwiddie (G)...
#   Processing data for Ben Simmons...
#     Cluster percentages for Ben Simmons:
# pred_cluster
# 0    63.333333
# 1    20.000000
# 3    13.333333
# 2     3.333333
# Name: proportion, dtype: float64
#   Processing data for Spencer Dinwiddie...
#     Cluster percentages for Spencer Dinwiddie:
# pred_cluster
# 3    46.315789
# 0    46.315789
# 1     7.368421
# Name: proportion, dtype: float64
#     Target player Spencer Dinwiddie cluster percentages:
# pred_cluster
# 3    46.315789
# 0    46.315789
# 1     7.368421
# Name: proportion, dtype: float64
#     The traded player Spencer Dinwiddie is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Dewayne Dedmon (C)...
#   Processing data for Brook Lopez...
#     Cluster percentages for Brook Lopez:
# pred_cluster
# 1    64.516129
# 0    30.645161
# 3     4.838710
# Name: proportion, dtype: float64
#   Processing data for Jakob Pöltl...
#     Cluster percentages for Jakob Pöltl:
# pred_cluster
# 1    74.324324
# 0    22.972973
# 3     2.702703
# Name: proportion, dtype: float64
#   Processing data for Dewayne Dedmon...
#     Cluster percentages for Dewayne Dedmon:
# pred_cluster
# 0    92.207792
# 2     6.493506
# 1     1.298701
# Name: proportion, dtype: float64
#     Target player Dewayne Dedmon cluster percentages:
# pred_cluster
# 0    92.207792
# 2     6.493506
# 1     1.298701
# Name: proportion, dtype: float64
#     The traded player Dewayne Dedmon is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Kessler Edwards (F)...
#   Processing data for Jae Crowder...
#     Cluster percentages for Jae Crowder:
# pred_cluster
# 1    66.666667
# 0    29.166667
# 3     4.166667
# Name: proportion, dtype: float64
#   Processing data for Nassir Little...
#     Cluster percentages for Nassir Little:
# pred_cluster
# 0    65.789474
# 1    23.684211
# 3     7.894737
# 2     2.631579
# Name: proportion, dtype: float64
#   Processing data for T.J. Warren...
#     Cluster percentages for T.J. Warren:
# pred_cluster
# 0    75.000000
# 1    16.666667
# 2     8.333333
# Name: proportion, dtype: float64
#   Processing data for P.J. Washington...
#     Cluster percentages for P.J. Washington:
# pred_cluster
# 1    57.142857
# 0    23.809524
# 3    19.047619
# Name: proportion, dtype: float64
#   Processing data for Kyle Kuzma...
#     Cluster percentages for Kyle Kuzma:
# pred_cluster
# 1    68.493151
# 3    27.397260
# 0     4.109589
# Name: proportion, dtype: float64
#   Processing data for Kessler Edwards...
#     Cluster percentages for Kessler Edwards:
# pred_cluster
# 2    36.507937
# 0    31.746032
# 1    30.158730
# 3     1.587302
# Name: proportion, dtype: float64
#     Target player Kessler Edwards cluster percentages:
# pred_cluster
# 2    36.507937
# 0    31.746032
# 1    30.158730
# 3     1.587302
# Name: proportion, dtype: float64
#     The traded player Kessler Edwards is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Jakob Pöltl (C)...
#   Processing data for Coby White...
#     Cluster percentages for Coby White:
# pred_cluster
# 0    50.602410
# 3    21.686747
# 1    21.686747
# 2     6.024096
# Name: proportion, dtype: float64
#   Processing data for Mike Muscala...
#     Cluster percentages for Mike Muscala:
# pred_cluster
# 0    90.243902
# 1     4.878049
# 3     2.439024
# 2     2.439024
# Name: proportion, dtype: float64
#   Processing data for Jakob Pöltl...
#     Cluster percentages for Jakob Pöltl:
# pred_cluster
# 1    74.324324
# 0    22.972973
# 3     2.702703
# Name: proportion, dtype: float64
#     Target player Jakob Pöltl cluster percentages:
# pred_cluster
# 1    74.324324
# 0    22.972973
# 3     2.702703
# Name: proportion, dtype: float64
#     The traded player Jakob Pöltl is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for D'Angelo Russell (G)...
#   Processing data for Buddy Hield...
#     Cluster percentages for Buddy Hield:
# pred_cluster
# 1    47.058824
# 3    38.823529
# 0    14.117647
# Name: proportion, dtype: float64
#   Processing data for Kyrie Irving...
#     Cluster percentages for Kyrie Irving:
# pred_cluster
# 3    76.190476
# 1    19.047619
# 0     4.761905
# Name: proportion, dtype: float64
#   Processing data for Fred VanVleet...
#     Cluster percentages for Fred VanVleet:
# pred_cluster
# 3    76.712329
# 1    13.698630
# 0     9.589041
# Name: proportion, dtype: float64
#   Processing data for Jordan Clarkson...
#     Cluster percentages for Jordan Clarkson:
# pred_cluster
# 3    48.913043
# 0    28.260870
# 1    22.826087
# Name: proportion, dtype: float64
#   Processing data for Zach LaVine...
#     Cluster percentages for Zach LaVine:
# pred_cluster
# 3    68.421053
# 1    19.736842
# 0    10.526316
# 2     1.315789
# Name: proportion, dtype: float64
#   Processing data for D'Angelo Russell...
#     Cluster percentages for D'Angelo Russell:
# pred_cluster
# 3    76.190476
# 0    21.428571
# 1     2.380952
# Name: proportion, dtype: float64
#     Target player D'Angelo Russell cluster percentages:
# pred_cluster
# 3    76.190476
# 0    21.428571
# 1     2.380952
# Name: proportion, dtype: float64
#     The traded player D'Angelo Russell is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Malik Beasley (F)...
#   Processing data for Dorian Finney-Smith...
#     Cluster percentages for Dorian Finney-Smith:
# pred_cluster
# 1    66.326531
# 0    17.346939
# 3    16.326531
# Name: proportion, dtype: float64
#   Processing data for Kyle Kuzma...
#     Cluster percentages for Kyle Kuzma:
# pred_cluster
# 1    68.493151
# 3    27.397260
# 0     4.109589
# Name: proportion, dtype: float64
#   Processing data for Jerami Grant...
#     Cluster percentages for Jerami Grant:
# pred_cluster
# 3    48.333333
# 1    35.000000
# 0    16.666667
# Name: proportion, dtype: float64
#   Processing data for Cam Reddish...
#     Cluster percentages for Cam Reddish:
# pred_cluster
# 0    73.809524
# 1    16.666667
# 2     4.761905
# 3     4.761905
# Name: proportion, dtype: float64
#   Processing data for Caleb Martin...
#     Cluster percentages for Caleb Martin:
# pred_cluster
# 0    43.529412
# 1    40.000000
# 3     9.411765
# 2     7.058824
# Name: proportion, dtype: float64
#   Processing data for Malik Beasley...
#     Cluster percentages for Malik Beasley:
# pred_cluster
# 0    47.826087
# 1    43.478261
# 3     8.695652
# Name: proportion, dtype: float64
#     Target player Malik Beasley cluster percentages:
# pred_cluster
# 0    47.826087
# 1    43.478261
# 3     8.695652
# Name: proportion, dtype: float64
#     The traded player Malik Beasley is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Jarred Vanderbilt (C)...
#   Processing data for Nikola Vučević...
#     Cluster percentages for Nikola Vučević:
# pred_cluster
# 1    89.130435
# 0     5.434783
# 3     5.434783
# Name: proportion, dtype: float64
#   Processing data for Walker Kessler...
#     Cluster percentages for Walker Kessler:
# pred_cluster
# 0    60.0
# 1    32.5
# 2     7.5
# Name: proportion, dtype: float64
#   Processing data for Nic Claxton...
#     Cluster percentages for Nic Claxton:
# pred_cluster
# 0    50.666667
# 1    48.000000
# 2     1.333333
# Name: proportion, dtype: float64
#   Processing data for Jarred Vanderbilt...
#     Cluster percentages for Jarred Vanderbilt:
# pred_cluster
# 1    55.434783
# 0    42.391304
# 2     2.173913
# Name: proportion, dtype: float64
#     Target player Jarred Vanderbilt cluster percentages:
# pred_cluster
# 1    55.434783
# 0    42.391304
# 2     2.173913
# Name: proportion, dtype: float64
#     The traded player Jarred Vanderbilt is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Mike Conley (G)...
#   Processing data for Tyus Jones...
#     Cluster percentages for Tyus Jones:
# pred_cluster
# 0    78.409091
# 3    13.636364
# 1     4.545455
# 2     3.409091
# Name: proportion, dtype: float64
#   Processing data for Dennis Smith Jr....
#     Cluster percentages for Dennis Smith Jr.:
# pred_cluster
# 0    65.789474
# 3    26.315789
# 2     7.894737
# Name: proportion, dtype: float64
#   Processing data for Monté Morris...
#     Cluster percentages for Monté Morris:
# pred_cluster
# 0    51.190476
# 3    30.952381
# 1    17.857143
# Name: proportion, dtype: float64
#   Processing data for Mike Conley...
#     Cluster percentages for Mike Conley:
# pred_cluster
# 0    50.000000
# 3    47.435897
# 2     1.282051
# 1     1.282051
# Name: proportion, dtype: float64
#     Target player Mike Conley cluster percentages:
# pred_cluster
# 0    50.000000
# 3    47.435897
# 2     1.282051
# 1     1.282051
# Name: proportion, dtype: float64
#     The traded player Mike Conley is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Nickeil Alexander-Walker (F)...
#   Processing data for Damion Lee...
#     Cluster percentages for Damion Lee:
# pred_cluster
# 0    60.000000
# 1    27.368421
# 2    12.631579
# Name: proportion, dtype: float64
#   Processing data for Julian Champagnie...
#     Cluster percentages for Julian Champagnie:
# pred_cluster
# 2    50.0
# 0    50.0
# Name: proportion, dtype: float64
#   Processing data for Norman Powell...
#     Cluster percentages for Norman Powell:
# pred_cluster
# 0    47.826087
# 1    39.130435
# 3    13.043478
# Name: proportion, dtype: float64
#   Processing data for Nickeil Alexander-Walker...
#     Cluster percentages for Nickeil Alexander-Walker:
# pred_cluster
# 0    59.3750
# 2    23.4375
# 3     9.3750
# 1     7.8125
# Name: proportion, dtype: float64
#     Target player Nickeil Alexander-Walker cluster percentages:
# pred_cluster
# 0    59.3750
# 2    23.4375
# 3     9.3750
# 1     7.8125
# Name: proportion, dtype: float64
#     The traded player Nickeil Alexander-Walker is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Russell Westbrook (G)...
#   Processing data for Derrick Rose...
#     Cluster percentages for Derrick Rose:
# pred_cluster
# 0    93.103448
# 2     6.896552
# Name: proportion, dtype: float64
#   Processing data for Kyle Lowry...
#     Cluster percentages for Kyle Lowry:
# pred_cluster
# 3    57.894737
# 0    26.315789
# 1    15.789474
# Name: proportion, dtype: float64
#   Processing data for Jordan Clarkson...
#     Cluster percentages for Jordan Clarkson:
# pred_cluster
# 3    48.913043
# 0    28.260870
# 1    22.826087
# Name: proportion, dtype: float64
#   Processing data for Tyrese Haliburton...
#     Cluster percentages for Tyrese Haliburton:
# pred_cluster
# 3    79.746835
# 0    13.924051
# 1     6.329114
# Name: proportion, dtype: float64
#   Processing data for Russell Westbrook...
#     Cluster percentages for Russell Westbrook:
# pred_cluster
# 3    58.974359
# 1    20.512821
# 0    19.230769
# 2     1.282051
# Name: proportion, dtype: float64
#     Target player Russell Westbrook cluster percentages:
# pred_cluster
# 3    58.974359
# 1    20.512821
# 0    19.230769
# 2     1.282051
# Name: proportion, dtype: float64
#     The traded player Russell Westbrook is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Juan Toscano-Anderson (F)...
#   Processing data for Gary Trent Jr....
#     Cluster percentages for Gary Trent Jr.:
# pred_cluster
# 3    58.75
# 1    30.00
# 0    10.00
# 2     1.25
# Name: proportion, dtype: float64
#   Processing data for Jerami Grant...
#     Cluster percentages for Jerami Grant:
# pred_cluster
# 3    48.333333
# 1    35.000000
# 0    16.666667
# Name: proportion, dtype: float64
#   Processing data for Andrew Wiggins...
#     Cluster percentages for Andrew Wiggins:
# pred_cluster
# 1    56.521739
# 3    28.260870
# 0    15.217391
# Name: proportion, dtype: float64
#   Processing data for Joe Ingles...
#     Cluster percentages for Joe Ingles:
# pred_cluster
# 0    70.588235
# 2    17.647059
# 3     5.882353
# 1     5.882353
# Name: proportion, dtype: float64
#   Processing data for T.J. Warren...
#     Cluster percentages for T.J. Warren:
# pred_cluster
# 0    75.000000
# 1    16.666667
# 2     8.333333
# Name: proportion, dtype: float64
#   Processing data for Juan Toscano-Anderson...
#     Cluster percentages for Juan Toscano-Anderson:
# pred_cluster
# 0    57.333333
# 2    37.333333
# 1     5.333333
# Name: proportion, dtype: float64
#     Target player Juan Toscano-Anderson cluster percentages:
# pred_cluster
# 0    57.333333
# 2    37.333333
# 1     5.333333
# Name: proportion, dtype: float64
#     The traded player Juan Toscano-Anderson is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Damian Jones (C)...
#   Processing data for Isaiah Hartenstein...
#     Cluster percentages for Isaiah Hartenstein:
# pred_cluster
# 0    75.609756
# 1    18.292683
# 2     4.878049
# 3     1.219512
# Name: proportion, dtype: float64
#   Processing data for Damian Jones...
#     Cluster percentages for Damian Jones:
# pred_cluster
# 0    59.322034
# 1    25.423729
# 2    13.559322
# 3     1.694915
# Name: proportion, dtype: float64
#     Target player Damian Jones cluster percentages:
# pred_cluster
# 0    59.322034
# 1    25.423729
# 2    13.559322
# 3     1.694915
# Name: proportion, dtype: float64
#     The traded player Damian Jones is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Mo Bamba (C)...
#   Processing data for Bismack Biyombo...
#     Cluster percentages for Bismack Biyombo:
# pred_cluster
# 0    49.350649
# 2    31.168831
# 1    19.480519
# Name: proportion, dtype: float64
#   Processing data for Isaiah Stewart...
#     Cluster percentages for Isaiah Stewart:
# pred_cluster
# 1    79.746835
# 0    18.987342
# 2     1.265823
# Name: proportion, dtype: float64
#   Processing data for Steven Adams...
#     Cluster percentages for Steven Adams:
# pred_cluster
# 1    54.878049
# 0    42.682927
# 2     2.439024
# Name: proportion, dtype: float64
#   Processing data for Mo Bamba...
#     Cluster percentages for Mo Bamba:
# pred_cluster
# 0    50.632911
# 1    41.772152
# 2     6.329114
# 3     1.265823
# Name: proportion, dtype: float64
#     Target player Mo Bamba cluster percentages:
# pred_cluster
# 0    50.632911
# 1    41.772152
# 2     6.329114
# 3     1.265823
# Name: proportion, dtype: float64
#     The traded player Mo Bamba is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Patrick Beverley (G)...
#   Processing data for D'Angelo Russell...
#     Cluster percentages for D'Angelo Russell:
# pred_cluster
# 3    76.190476
# 0    21.428571
# 1     2.380952
# Name: proportion, dtype: float64
#   Processing data for Buddy Hield...
#     Cluster percentages for Buddy Hield:
# pred_cluster
# 1    47.058824
# 3    38.823529
# 0    14.117647
# Name: proportion, dtype: float64
#   Processing data for Patrick Beverley...
#     Cluster percentages for Patrick Beverley:
# pred_cluster
# 0    55.405405
# 1    24.324324
# 3    18.918919
# 2     1.351351
# Name: proportion, dtype: float64
#     Target player Patrick Beverley cluster percentages:
# pred_cluster
# 0    55.405405
# 1    24.324324
# 3    18.918919
# 2     1.351351
# Name: proportion, dtype: float64
#     The traded player Patrick Beverley is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Bruno Fernando (C)...
#   Processing data for Jakob Pöltl...
#     Cluster percentages for Jakob Pöltl:
# pred_cluster
# 1    74.324324
# 0    22.972973
# 3     2.702703
# Name: proportion, dtype: float64
#   Processing data for Mason Plumlee...
#     Cluster percentages for Mason Plumlee:
# pred_cluster
# 0    57.303371
# 1    41.573034
# 3     1.123596
# Name: proportion, dtype: float64
#   Processing data for Mo Bamba...
#     Cluster percentages for Mo Bamba:
# pred_cluster
# 0    50.632911
# 1    41.772152
# 2     6.329114
# 3     1.265823
# Name: proportion, dtype: float64
#   Processing data for Bruno Fernando...
#     Cluster percentages for Bruno Fernando:
# pred_cluster
# 0    74.418605
# 2    20.930233
# 1     4.651163
# Name: proportion, dtype: float64
#     Target player Bruno Fernando cluster percentages:
# pred_cluster
# 0    74.418605
# 2    20.930233
# 1     4.651163
# Name: proportion, dtype: float64
#     The traded player Bruno Fernando is NOT in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Garrison Mathews (G)...
#   Processing data for Malcolm Brogdon...
#     Cluster percentages for Malcolm Brogdon:
# pred_cluster
# 0    65.116279
# 3    25.581395
# 1     9.302326
# Name: proportion, dtype: float64
#   Processing data for Jordan Clarkson...
#     Cluster percentages for Jordan Clarkson:
# pred_cluster
# 3    48.913043
# 0    28.260870
# 1    22.826087
# Name: proportion, dtype: float64
#   Processing data for Garrison Mathews...
#     Cluster percentages for Garrison Mathews:
# pred_cluster
# 0    51.948052
# 1    29.870130
# 2    11.688312
# 3     6.493506
# Name: proportion, dtype: float64
#     Target player Garrison Mathews cluster percentages:
# pred_cluster
# 0    51.948052
# 1    29.870130
# 2    11.688312
# 3     6.493506
# Name: proportion, dtype: float64
#     The traded player Garrison Mathews is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Dario Šarić (C)...
#   Processing data for Jalen Smith...
#     Cluster percentages for Jalen Smith:
# pred_cluster
# 1    49.350649
# 0    44.155844
# 2     6.493506
# Name: proportion, dtype: float64
#   Processing data for Isaiah Hartenstein...
#     Cluster percentages for Isaiah Hartenstein:
# pred_cluster
# 0    75.609756
# 1    18.292683
# 2     4.878049
# 3     1.219512
# Name: proportion, dtype: float64
#   Processing data for Dario Šarić...
#     Cluster percentages for Dario Šarić:
# pred_cluster
# 0    65.0
# 2    35.0
# Name: proportion, dtype: float64
#     Target player Dario Šarić cluster percentages:
# pred_cluster
# 0    65.0
# 2    35.0
# Name: proportion, dtype: float64
#     The traded player Dario Šarić is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for James Wiseman (C)...
#   Processing data for OG Anunoby...
#     Cluster percentages for OG Anunoby:
# pred_cluster
# 1    59.459459
# 3    31.081081
# 0     9.459459
# Name: proportion, dtype: float64
#   Processing data for James Wiseman...
#     Cluster percentages for James Wiseman:
# pred_cluster
# 0    75.0
# 2    12.5
# 1    12.5
# Name: proportion, dtype: float64
#     Target player James Wiseman cluster percentages:
# pred_cluster
# 0    75.0
# 2    12.5
# 1    12.5
# Name: proportion, dtype: float64
#     The traded player James Wiseman is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Saddiq Bey (F)...
#   Processing data for John Collins...
#     Cluster percentages for John Collins:
# pred_cluster
# 1    72.881356
# 0    23.728814
# 3     3.389831
# Name: proportion, dtype: float64
#   Processing data for OG Anunoby...
#     Cluster percentages for OG Anunoby:
# pred_cluster
# 1    59.459459
# 3    31.081081
# 0     9.459459
# Name: proportion, dtype: float64
#   Processing data for Jaylen Brown...
#     Cluster percentages for Jaylen Brown:
# pred_cluster
# 1    48.113208
# 3    44.339623
# 0     7.547170
# Name: proportion, dtype: float64
#   Processing data for Patrick Williams...
#     Cluster percentages for Patrick Williams:
# pred_cluster
# 1    56.140351
# 0    28.070175
# 3    15.789474
# Name: proportion, dtype: float64
#   Processing data for Saddiq Bey...
#     Cluster percentages for Saddiq Bey:
# pred_cluster
# 1    51.136364
# 3    32.954545
# 0    15.909091
# Name: proportion, dtype: float64
#     Target player Saddiq Bey cluster percentages:
# pred_cluster
# 1    51.136364
# 3    32.954545
# 0    15.909091
# Name: proportion, dtype: float64
#     The traded player Saddiq Bey is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Josh Richardson (G)...
#   Processing data for Josh Hart...
#     Cluster percentages for Josh Hart:
# pred_cluster
# 1    70.3125
# 3    17.1875
# 0    12.5000
# Name: proportion, dtype: float64
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    56.097561
# 1    23.170732
# 2    18.292683
# 3     2.439024
# Name: proportion, dtype: float64
#   Processing data for Josh Richardson...
#     Cluster percentages for Josh Richardson:
# pred_cluster
# 0    70.422535
# 1    14.084507
# 3    12.676056
# 2     2.816901
# Name: proportion, dtype: float64
#     Target player Josh Richardson cluster percentages:
# pred_cluster
# 0    70.422535
# 1    14.084507
# 3    12.676056
# 2     2.816901
# Name: proportion, dtype: float64
#     The traded player Josh Richardson is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Devonte' Graham (G)...
#   Processing data for Tyus Jones...
#     Cluster percentages for Tyus Jones:
# pred_cluster
# 0    78.409091
# 3    13.636364
# 1     4.545455
# 2     3.409091
# Name: proportion, dtype: float64
#   Processing data for Anfernee Simons...
#     Cluster percentages for Anfernee Simons:
# pred_cluster
# 3    89.0625
# 1     6.2500
# 0     4.6875
# Name: proportion, dtype: float64
#   Processing data for Jaden Ivey...
#     Cluster percentages for Jaden Ivey:
# pred_cluster
# 3    58.974359
# 0    23.076923
# 1    17.948718
# Name: proportion, dtype: float64
#   Processing data for Devonte' Graham...
#     Cluster percentages for Devonte' Graham:
# pred_cluster
# 0    65.591398
# 3    20.430108
# 2    10.752688
# 1     3.225806
# Name: proportion, dtype: float64
#     Target player Devonte' Graham cluster percentages:
# pred_cluster
# 0    65.591398
# 3    20.430108
# 2    10.752688
# 1     3.225806
# Name: proportion, dtype: float64
#     The traded player Devonte' Graham is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Jalen McDaniels (F)...
#   Processing data for Kelly Oubre Jr....
#     Cluster percentages for Kelly Oubre Jr.:
# pred_cluster
# 1    47.5
# 0    32.5
# 3    20.0
# Name: proportion, dtype: float64
#   Processing data for T.J. Warren...
#     Cluster percentages for T.J. Warren:
# pred_cluster
# 0    75.000000
# 1    16.666667
# 2     8.333333
# Name: proportion, dtype: float64
#   Processing data for Danuel House Jr....
#     Cluster percentages for Danuel House Jr.:
# pred_cluster
# 0    76.190476
# 1    15.873016
# 2     6.349206
# 3     1.587302
# Name: proportion, dtype: float64
#   Processing data for Jalen McDaniels...
#     Cluster percentages for Jalen McDaniels:
# pred_cluster
# 0    71.014493
# 1    23.188406
# 3     4.347826
# 2     1.449275
# Name: proportion, dtype: float64
#     Target player Jalen McDaniels cluster percentages:
# pred_cluster
# 0    71.014493
# 1    23.188406
# 3     4.347826
# 2     1.449275
# Name: proportion, dtype: float64
#     The traded player Jalen McDaniels is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Cam Reddish (F)...
#   Processing data for Kelly Oubre Jr....
#     Cluster percentages for Kelly Oubre Jr.:
# pred_cluster
# 1    47.5
# 0    32.5
# 3    20.0
# Name: proportion, dtype: float64
#   Processing data for Miles Bridges...
#     Cluster percentages for Miles Bridges:
# pred_cluster
# 1    53.191489
# 3    36.170213
# 0    10.638298
# Name: proportion, dtype: float64
#   Processing data for Cam Reddish...
#     Cluster percentages for Cam Reddish:
# pred_cluster
# 0    73.809524
# 1    16.666667
# 2     4.761905
# 3     4.761905
# Name: proportion, dtype: float64
#     Target player Cam Reddish cluster percentages:
# pred_cluster
# 0    73.809524
# 1    16.666667
# 2     4.761905
# 3     4.761905
# Name: proportion, dtype: float64
#     The traded player Cam Reddish is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Matisse Thybulle (F)...
#   Processing data for Josh Hart...
#     Cluster percentages for Josh Hart:
# pred_cluster
# 1    70.3125
# 3    17.1875
# 0    12.5000
# Name: proportion, dtype: float64
#   Processing data for Justise Winslow...
#     Cluster percentages for Justise Winslow:
# pred_cluster
# 0    61.538462
# 1    23.076923
# 3    11.538462
# 2     3.846154
# Name: proportion, dtype: float64
#   Processing data for Nassir Little...
#     Cluster percentages for Nassir Little:
# pred_cluster
# 0    65.789474
# 1    23.684211
# 3     7.894737
# 2     2.631579
# Name: proportion, dtype: float64
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    56.097561
# 1    23.170732
# 2    18.292683
# 3     2.439024
# Name: proportion, dtype: float64
#     Target player Matisse Thybulle cluster percentages:
# pred_cluster
# 0    56.097561
# 1    23.170732
# 2    18.292683
# 3     2.439024
# Name: proportion, dtype: float64
#     The traded player Matisse Thybulle is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Ryan Arcidiacono (G)...
#   Processing data for Tyus Jones...
#     Cluster percentages for Tyus Jones:
# pred_cluster
# 0    78.409091
# 3    13.636364
# 1     4.545455
# 2     3.409091
# Name: proportion, dtype: float64
#   Processing data for Lonnie Walker IV...
#     Cluster percentages for Lonnie Walker IV:
# pred_cluster
# 0    39.726027
# 1    30.136986
# 3    27.397260
# 2     2.739726
# Name: proportion, dtype: float64
#   Processing data for Ryan Arcidiacono...
#     Cluster percentages for Ryan Arcidiacono:
# pred_cluster
# 2    68.181818
# 0    31.818182
# Name: proportion, dtype: float64
#     Target player Ryan Arcidiacono cluster percentages:
# pred_cluster
# 2    68.181818
# 0    31.818182
# Name: proportion, dtype: float64
#     The traded player Ryan Arcidiacono is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Mason Plumlee (C)...
#   Processing data for Daniel Theis...
#     Cluster percentages for Daniel Theis:
# pred_cluster
# 0    66.666667
# 1    19.047619
# 2    14.285714
# Name: proportion, dtype: float64
#   Processing data for Mike Muscala...
#     Cluster percentages for Mike Muscala:
# pred_cluster
# 0    90.243902
# 1     4.878049
# 3     2.439024
# 2     2.439024
# Name: proportion, dtype: float64
#   Processing data for Naz Reid...
#     Cluster percentages for Naz Reid:
# pred_cluster
# 0    78.160920
# 1    16.091954
# 2     5.747126
# Name: proportion, dtype: float64
#   Processing data for Mason Plumlee...
#     Cluster percentages for Mason Plumlee:
# pred_cluster
# 0    57.303371
# 1    41.573034
# 3     1.123596
# Name: proportion, dtype: float64
#     Target player Mason Plumlee cluster percentages:
# pred_cluster
# 0    57.303371
# 1    41.573034
# 3     1.123596
# Name: proportion, dtype: float64
#     The traded player Mason Plumlee is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Kevin Durant (F)...
#   Processing data for John Collins...
#     Cluster percentages for John Collins:
# pred_cluster
# 1    72.881356
# 0    23.728814
# 3     3.389831
# Name: proportion, dtype: float64
#   Processing data for Kyle Kuzma...
#     Cluster percentages for Kyle Kuzma:
# pred_cluster
# 1    68.493151
# 3    27.397260
# 0     4.109589
# Name: proportion, dtype: float64
#   Processing data for OG Anunoby...
#     Cluster percentages for OG Anunoby:
# pred_cluster
# 1    59.459459
# 3    31.081081
# 0     9.459459
# Name: proportion, dtype: float64
#   Processing data for Kevin Durant...
#     Cluster percentages for Kevin Durant:
# pred_cluster
# 3    70.422535
# 1    25.352113
# 0     4.225352
# Name: proportion, dtype: float64
#     Target player Kevin Durant cluster percentages:
# pred_cluster
# 3    70.422535
# 1    25.352113
# 0     4.225352
# Name: proportion, dtype: float64
#     The traded player Kevin Durant is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Mikal Bridges (G)...
#   Processing data for Keldon Johnson...
#     Cluster percentages for Keldon Johnson:
# pred_cluster
# 1    53.246753
# 3    35.064935
# 0    11.688312
# Name: proportion, dtype: float64
#   Processing data for Donovan Mitchell...
#     Cluster percentages for Donovan Mitchell:
# pred_cluster
# 3    84.415584
# 0     9.090909
# 1     6.493506
# Name: proportion, dtype: float64
#   Processing data for Mikal Bridges...
#     Cluster percentages for Mikal Bridges:
# pred_cluster
# 1    64.0
# 3    27.0
# 0     8.0
# 2     1.0
# Name: proportion, dtype: float64
#     Target player Mikal Bridges cluster percentages:
# pred_cluster
# 1    64.0
# 3    27.0
# 0     8.0
# 2     1.0
# Name: proportion, dtype: float64
#     The traded player Mikal Bridges is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Cameron Johnson (F)...
#   Processing data for Jae Crowder...
#     Cluster percentages for Jae Crowder:
# pred_cluster
# 1    66.666667
# 0    29.166667
# 3     4.166667
# Name: proportion, dtype: float64
#   Processing data for Royce O'Neale...
#     Cluster percentages for Royce O'Neale:
# pred_cluster
# 1    60.227273
# 0    22.727273
# 3    17.045455
# Name: proportion, dtype: float64
#   Processing data for T.J. Warren...
#     Cluster percentages for T.J. Warren:
# pred_cluster
# 0    75.000000
# 1    16.666667
# 2     8.333333
# Name: proportion, dtype: float64
#   Processing data for Cameron Johnson...
#     Cluster percentages for Cameron Johnson:
# pred_cluster
# 0    44.444444
# 1    38.888889
# 3    12.962963
# 2     3.703704
# Name: proportion, dtype: float64
#     Target player Cameron Johnson cluster percentages:
# pred_cluster
# 0    44.444444
# 1    38.888889
# 3    12.962963
# 2     3.703704
# Name: proportion, dtype: float64
#     The traded player Cameron Johnson is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Jae Crowder (F)...
#   Processing data for P.J. Washington...
#     Cluster percentages for P.J. Washington:
# pred_cluster
# 1    57.142857
# 0    23.809524
# 3    19.047619
# Name: proportion, dtype: float64
#   Processing data for Gary Trent Jr....
#     Cluster percentages for Gary Trent Jr.:
# pred_cluster
# 3    58.75
# 1    30.00
# 0    10.00
# 2     1.25
# Name: proportion, dtype: float64
#   Processing data for Taurean Prince...
#     Cluster percentages for Taurean Prince:
# pred_cluster
# 0    76.388889
# 1    13.888889
# 2     6.944444
# 3     2.777778
# Name: proportion, dtype: float64
#   Processing data for Jae Crowder...
#     Cluster percentages for Jae Crowder:
# pred_cluster
# 1    66.666667
# 0    29.166667
# 3     4.166667
# Name: proportion, dtype: float64
#     Target player Jae Crowder cluster percentages:
# pred_cluster
# 1    66.666667
# 0    29.166667
# 3     4.166667
# Name: proportion, dtype: float64
#     The traded player Jae Crowder is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Serge Ibaka (C)...
#   Processing data for Jonas Valančiūnas...
#     Cluster percentages for Jonas Valančiūnas:
# pred_cluster
# 1    71.910112
# 0    28.089888
# Name: proportion, dtype: float64
#   Processing data for Walker Kessler...
#     Cluster percentages for Walker Kessler:
# pred_cluster
# 0    60.0
# 1    32.5
# 2     7.5
# Name: proportion, dtype: float64
#   Processing data for Kelly Olynyk...
#     Cluster percentages for Kelly Olynyk:
# pred_cluster
# 0    62.318841
# 1    21.739130
# 3    14.492754
# 2     1.449275
# Name: proportion, dtype: float64
#   Processing data for Serge Ibaka...
#     Cluster percentages for Serge Ibaka:
# pred_cluster
# 0    69.354839
# 2    19.354839
# 1    11.290323
# Name: proportion, dtype: float64
#     Target player Serge Ibaka cluster percentages:
# pred_cluster
# 0    69.354839
# 2    19.354839
# 1    11.290323
# Name: proportion, dtype: float64
#     The traded player Serge Ibaka is NOT in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Jordan Nwora (F)...
#   Processing data for Tobias Harris...
#     Cluster percentages for Tobias Harris:
# pred_cluster
# 1    72.631579
# 3    14.736842
# 0    12.631579
# Name: proportion, dtype: float64
#   Processing data for Jerami Grant...
#     Cluster percentages for Jerami Grant:
# pred_cluster
# 3    48.333333
# 1    35.000000
# 0    16.666667
# Name: proportion, dtype: float64
#   Processing data for Jordan Nwora...
#     Cluster percentages for Jordan Nwora:
# pred_cluster
# 0    50.684932
# 2    26.027397
# 1    20.547945
# 3     2.739726
# Name: proportion, dtype: float64
#     Target player Jordan Nwora cluster percentages:
# pred_cluster
# 0    50.684932
# 2    26.027397
# 1    20.547945
# 3     2.739726
# Name: proportion, dtype: float64
#     The traded player Jordan Nwora is in the top 3 candidates for the expected cluster (3).
#
# Overall accuracy for trades in 2023: 77.78%

# %%
main_pipeline(df_2022_2024, 2023, tuned_lgb, 'NBA_TRADE.csv', expected_clusters, 2024)
# Out:
# 2023 stats have been saved to 'nba_data_2023.csv'.
#
# Processing trade for P.J. Washington (F)...
#   Processing data for Jimmy Butler...
#     Cluster percentages for Jimmy Butler:
# pred_cluster
# 3    65.168539
# 1    25.842697
# 0     8.988764
# Name: proportion, dtype: float64
#   Processing data for Dorian Finney-Smith...
#     Cluster percentages for Dorian Finney-Smith:
# pred_cluster
# 1    58.904110
# 0    35.616438
# 3     4.109589
# 2     1.369863
# Name: proportion, dtype: float64
#   Processing data for Bogdan Bogdanović...
#     Cluster percentages for Bogdan Bogdanović:
# pred_cluster
# 0    52.439024
# 3    28.048780
# 1    19.512195
# Name: proportion, dtype: float64
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    55.405405
# 1    33.783784
# 2     6.756757
# 3     4.054054
# Name: proportion, dtype: float64
#   Processing data for P.J. Washington...
#     Cluster percentages for P.J. Washington:
# pred_cluster
# 1    57.352941
# 3    29.411765
# 0    11.764706
# 2     1.470588
# Name: proportion, dtype: float64
#     Target player P.J. Washington cluster percentages:
# pred_cluster
# 1    57.352941
# 3    29.411765
# 0    11.764706
# 2     1.470588
# Name: proportion, dtype: float64
#     The traded player P.J. Washington is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Grant Williams (F)...
#   Processing data for Mikal Bridges...
#     Cluster percentages for Mikal Bridges:
# pred_cluster
# 3    63.953488
# 1    26.744186
# 0     8.139535
# 2     1.162791
# Name: proportion, dtype: float64
#   Processing data for Brandon Ingram...
#     Cluster percentages for Brandon Ingram:
# pred_cluster
# 3    72.307692
# 1    18.461538
# 0     9.230769
# Name: proportion, dtype: float64
#   Processing data for Dejounte Murray...
#     Cluster percentages for Dejounte Murray:
# pred_cluster
# 3    69.411765
# 1    25.882353
# 0     4.705882
# Name: proportion, dtype: float64
#   Processing data for Donovan Mitchell...
#     Cluster percentages for Donovan Mitchell:
# pred_cluster
# 3    73.134328
# 1    19.402985
# 0     7.462687
# Name: proportion, dtype: float64
#   Processing data for Malcolm Brogdon...
#     Cluster percentages for Malcolm Brogdon:
# pred_cluster
# 0    48.780488
# 3    35.365854
# 1    10.975610
# 2     4.878049
# Name: proportion, dtype: float64
#   Processing data for Grant Williams...
#     Cluster percentages for Grant Williams:
# pred_cluster
# 0    48.387097
# 1    38.709677
# 2     6.451613
# 3     6.451613
# Name: proportion, dtype: float64
#     Target player Grant Williams cluster percentages:
# pred_cluster
# 0    48.387097
# 1    38.709677
# 2     6.451613
# 3     6.451613
# Name: proportion, dtype: float64
#     The traded player Grant Williams is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Seth Curry (G)...
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    55.405405
# 1    33.783784
# 2     6.756757
# 3     4.054054
# Name: proportion, dtype: float64
#   Processing data for Malcolm Brogdon...
#     Cluster percentages for Malcolm Brogdon:
# pred_cluster
# 0    48.780488
# 3    35.365854
# 1    10.975610
# 2     4.878049
# Name: proportion, dtype: float64
#   Processing data for Buddy Hield...
#     Cluster percentages for Buddy Hield:
# pred_cluster
# 1    49.367089
# 0    34.177215
# 3    16.455696
# Name: proportion, dtype: float64
#   Processing data for Eric Gordon...
#     Cluster percentages for Eric Gordon:
# pred_cluster
# 3    39.473684
# 0    35.526316
# 1    23.684211
# 2     1.315789
# Name: proportion, dtype: float64
#   Processing data for Dejounte Murray...
#     Cluster percentages for Dejounte Murray:
# pred_cluster
# 3    69.411765
# 1    25.882353
# 0     4.705882
# Name: proportion, dtype: float64
#   Processing data for Seth Curry...
#     Cluster percentages for Seth Curry:
# pred_cluster
# 0    69.117647
# 2    20.588235
# 3     8.823529
# 1     1.470588
# Name: proportion, dtype: float64
#     Target player Seth Curry cluster percentages:
# pred_cluster
# 0    69.117647
# 2    20.588235
# 3     8.823529
# 1     1.470588
# Name: proportion, dtype: float64
#     The traded player Seth Curry is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Buddy Hield (G)...
#   Processing data for Corey Kispert...
#     Cluster percentages for Corey Kispert:
# pred_cluster
# 0    55.0
# 1    37.5
# 3     7.5
# Name: proportion, dtype: float64
#   Processing data for Alex Caruso...
#     Cluster percentages for Alex Caruso:
# pred_cluster
# 0    67.647059
# 1    19.117647
# 3     8.823529
# 2     4.411765
# Name: proportion, dtype: float64
#   Processing data for Dorian Finney-Smith...
#     Cluster percentages for Dorian Finney-Smith:
# pred_cluster
# 1    58.904110
# 0    35.616438
# 3     4.109589
# 2     1.369863
# Name: proportion, dtype: float64
#   Processing data for Kyle Kuzma...
#     Cluster percentages for Kyle Kuzma:
# pred_cluster
# 1    51.612903
# 3    41.935484
# 0     6.451613
# Name: proportion, dtype: float64
#   Processing data for Nickeil Alexander-Walker...
#     Cluster percentages for Nickeil Alexander-Walker:
# pred_cluster
# 0    74.666667
# 2    10.666667
# 1     8.000000
# 3     6.666667
# Name: proportion, dtype: float64
#   Processing data for Buddy Hield...
#     Cluster percentages for Buddy Hield:
# pred_cluster
# 1    49.367089
# 0    34.177215
# 3    16.455696
# Name: proportion, dtype: float64
#     Target player Buddy Hield cluster percentages:
# pred_cluster
# 1    49.367089
# 0    34.177215
# 3    16.455696
# Name: proportion, dtype: float64
#     The traded player Buddy Hield is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Doug McDermott (F)...
#   Processing data for Buddy Hield...
#     Cluster percentages for Buddy Hield:
# pred_cluster
# 1    49.367089
# 0    34.177215
# 3    16.455696
# Name: proportion, dtype: float64
#   Processing data for Furkan Korkmaz...
#     Cluster percentages for Furkan Korkmaz:
# pred_cluster
# 0    61.904762
# 2    33.333333
# 1     4.761905
# Name: proportion, dtype: float64
#   Processing data for Doug McDermott...
#     Cluster percentages for Doug McDermott:
# pred_cluster
# 0    79.104478
# 2    13.432836
# 1     5.970149
# 3     1.492537
# Name: proportion, dtype: float64
#     Target player Doug McDermott cluster percentages:
# pred_cluster
# 0    79.104478
# 2    13.432836
# 1     5.970149
# 3     1.492537
# Name: proportion, dtype: float64
#     The traded player Doug McDermott is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Royce O'Neale (F)...
#   Processing data for Dorian Finney-Smith...
#     Cluster percentages for Dorian Finney-Smith:
# pred_cluster
# 1    58.904110
# 0    35.616438
# 3     4.109589
# 2     1.369863
# Name: proportion, dtype: float64
#   Processing data for Isaac Okoro...
#     Cluster percentages for Isaac Okoro:
# pred_cluster
# 0    67.605634
# 1    26.760563
# 3     4.225352
# 2     1.408451
# Name: proportion, dtype: float64
#   Processing data for Andre Drummond...
#     Cluster percentages for Andre Drummond:
# pred_cluster
# 0    88.461538
# 1     7.692308
# 2     3.846154
# Name: proportion, dtype: float64
#   Processing data for Jae'Sean Tate...
#     Cluster percentages for Jae'Sean Tate:
# pred_cluster
# 0    81.967213
# 1    13.114754
# 2     3.278689
# 3     1.639344
# Name: proportion, dtype: float64
#   Processing data for Miles Bridges...
#     Cluster percentages for Miles Bridges:
# pred_cluster
# 1    73.684211
# 3    26.315789
# Name: proportion, dtype: float64
#   Processing data for Royce O'Neale...
#     Cluster percentages for Royce O'Neale:
# pred_cluster
# 0    53.658537
# 1    34.146341
# 3    12.195122
# Name: proportion, dtype: float64
#     Target player Royce O'Neale cluster percentages:
# pred_cluster
# 0    53.658537
# 1    34.146341
# 3    12.195122
# Name: proportion, dtype: float64
#     The traded player Royce O'Neale is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for David Roddy (F)...
#   Processing data for Andre Drummond...
#     Cluster percentages for Andre Drummond:
# pred_cluster
# 0    88.461538
# 1     7.692308
# 2     3.846154
# Name: proportion, dtype: float64
#   Processing data for Alex Caruso...
#     Cluster percentages for Alex Caruso:
# pred_cluster
# 0    67.647059
# 1    19.117647
# 3     8.823529
# 2     4.411765
# Name: proportion, dtype: float64
#   Processing data for T.J. McConnell...
#     Cluster percentages for T.J. McConnell:
# pred_cluster
# 0    81.159420
# 3    11.594203
# 2     4.347826
# 1     2.898551
# Name: proportion, dtype: float64
#   Processing data for Robert Williams III...
#     Cluster percentages for Robert Williams III:
# pred_cluster
# 0    56.363636
# 1    41.818182
# 2     1.818182
# Name: proportion, dtype: float64
#   Processing data for David Roddy...
#     Cluster percentages for David Roddy:
# pred_cluster
# 0    62.820513
# 1    23.076923
# 2    11.538462
# 3     2.564103
# Name: proportion, dtype: float64
#     Target player David Roddy cluster percentages:
# pred_cluster
# 0    62.820513
# 1    23.076923
# 2    11.538462
# 3     2.564103
# Name: proportion, dtype: float64
#     The traded player David Roddy is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Chimezie Metu (C)...
#   Processing data for Chimezie Metu...
#     Cluster percentages for Chimezie Metu:
# pred_cluster
# 0    78.873239
# 2    15.492958
# 1     5.633803
# Name: proportion, dtype: float64
#   Processing data for Andre Drummond...
#     Cluster percentages for Andre Drummond:
# pred_cluster
# 0    88.461538
# 1     7.692308
# 2     3.846154
# Name: proportion, dtype: float64
#   Processing data for Alex Caruso...
#     Cluster percentages for Alex Caruso:
# pred_cluster
# 0    67.647059
# 1    19.117647
# 3     8.823529
# 2     4.411765
# Name: proportion, dtype: float64
#   Processing data for T.J. McConnell...
#     Cluster percentages for T.J. McConnell:
# pred_cluster
# 0    81.159420
# 3    11.594203
# 2     4.347826
# 1     2.898551
# Name: proportion, dtype: float64
#   Processing data for Robert Williams III...
#     Cluster percentages for Robert Williams III:
# pred_cluster
# 0    56.363636
# 1    41.818182
# 2     1.818182
# Name: proportion, dtype: float64
#   Processing data for Kelly Olynyk...
#     Cluster percentages for Kelly Olynyk:
# pred_cluster
# 0    52.941176
# 1    36.764706
# 3     7.352941
# 2     2.941176
# Name: proportion, dtype: float64
#     Target player Chimezie Metu cluster percentages:
# pred_cluster
# 0    78.873239
# 2    15.492958
# 1     5.633803
# Name: proportion, dtype: float64
#     The traded player Chimezie Metu is NOT in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Bojan Bogdanović (F)...
#   Processing data for Nikola Vučević...
#     Cluster percentages for Nikola Vučević:
# pred_cluster
# 1    91.566265
# 3     4.819277
# 0     3.614458
# Name: proportion, dtype: float64
#   Processing data for Isaiah Stewart...
#     Cluster percentages for Isaiah Stewart:
# pred_cluster
# 1    76.0
# 0    24.0
# Name: proportion, dtype: float64
#   Processing data for Jakob Pöltl...
#     Cluster percentages for Jakob Pöltl:
# pred_cluster
# 1    63.291139
# 0    36.708861
# Name: proportion, dtype: float64
#   Processing data for Jae'Sean Tate...
#     Cluster percentages for Jae'Sean Tate:
# pred_cluster
# 0    81.967213
# 1    13.114754
# 2     3.278689
# 3     1.639344
# Name: proportion, dtype: float64
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    55.405405
# 1    33.783784
# 2     6.756757
# 3     4.054054
# Name: proportion, dtype: float64
#   Processing data for Bojan Bogdanović...
#     Cluster percentages for Bojan Bogdanović:
# pred_cluster
# 3    50.000000
# 1    47.058824
# 0     2.941176
# Name: proportion, dtype: float64
#     Target player Bojan Bogdanović cluster percentages:
# pred_cluster
# 3    50.000000
# 1    47.058824
# 0     2.941176
# Name: proportion, dtype: float64
#     The traded player Bojan Bogdanović is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Steven Adams (C)...
#   Processing data for Nikola Vučević...
#     Cluster percentages for Nikola Vučević:
# pred_cluster
# 1    91.566265
# 3     4.819277
# 0     3.614458
# Name: proportion, dtype: float64
#   Processing data for Jonas Valančiūnas...
#     Cluster percentages for Jonas Valančiūnas:
# pred_cluster
# 1    70.370370
# 0    25.925926
# 2     2.469136
# 3     1.234568
# Name: proportion, dtype: float64
#   Processing data for Julius Randle...
#     Cluster percentages for Julius Randle:
# pred_cluster
# 1    76.744186
# 3    16.279070
# 0     6.976744
# Name: proportion, dtype: float64
#   Processing data for Brandon Ingram...
#     Cluster percentages for Brandon Ingram:
# pred_cluster
# 3    72.307692
# 1    18.461538
# 0     9.230769
# Name: proportion, dtype: float64
#   Processing data for Matisse Thybulle...
#     Cluster percentages for Matisse Thybulle:
# pred_cluster
# 0    55.405405
# 1    33.783784
# 2     6.756757
# 3     4.054054
# Name: proportion, dtype: float64
#   Processing data for Steven Adams...
#     Cluster percentages for Steven Adams:
# pred_cluster
# 1    83.333333
# 0    16.666667
# Name: proportion, dtype: float64
#     Target player Steven Adams cluster percentages:
# pred_cluster
# 1    83.333333
# 0    16.666667
# Name: proportion, dtype: float64
#     The traded player Steven Adams is in the top 3 candidates for the expected cluster (1).
#
# Processing trade for Gordon Hayward (F)...
#   Processing data for Lauri Markkanen...
#     Cluster percentages for Lauri Markkanen:
# pred_cluster
# 1    89.655172
# 3     6.896552
# 0     3.448276
# Name: proportion, dtype: float64
#   Processing data for Wendell Carter Jr....
#     Cluster percentages for Wendell Carter Jr.:
# pred_cluster
# 1    73.584906
# 0    24.528302
# 2     1.886792
# Name: proportion, dtype: float64
#   Processing data for Mikal Bridges...
#     Cluster percentages for Mikal Bridges:
# pred_cluster
# 3    63.953488
# 1    26.744186
# 0     8.139535
# 2     1.162791
# Name: proportion, dtype: float64
#   Processing data for Gordon Hayward...
#     Cluster percentages for Gordon Hayward:
# pred_cluster
# 3    54.385965
# 0    24.561404
# 1    21.052632
# Name: proportion, dtype: float64
#     Target player Gordon Hayward cluster percentages:
# pred_cluster
# 3    54.385965
# 0    24.561404
# 1    21.052632
# Name: proportion, dtype: float64
#     The traded player Gordon Hayward is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Alec Burks (G)...
#   Processing data for Malik Monk...
#     Cluster percentages for Malik Monk:
# pred_cluster
# 0    69.411765
# 3    21.176471
# 1     9.411765
# Name: proportion, dtype: float64
#   Processing data for Kentavious Caldwell-Pope...
#     Cluster percentages for Kentavious Caldwell-Pope:
# pred_cluster
# 1    45.918367
# 3    30.612245
# 0    23.469388
# Name: proportion, dtype: float64
#   Processing data for De'Anthony Melton...
#     Cluster percentages for De'Anthony Melton:
# pred_cluster
# 0    43.333333
# 1    37.777778
# 3    14.444444
# 2     4.444444
# Name: proportion, dtype: float64
#   Processing data for Landry Shamet...
#     Cluster percentages for Landry Shamet:
# pred_cluster
# 0    60.000000
# 2    20.000000
# 1    11.111111
# 3     8.888889
# Name: proportion, dtype: float64
#   Processing data for Derrick Jones Jr....
#     Cluster percentages for Derrick Jones Jr.:
# pred_cluster
# 0    59.210526
# 1    27.631579
# 2    10.526316
# 3     2.631579
# Name: proportion, dtype: float64
#   Processing data for Alec Burks...
#     Cluster percentages for Alec Burks:
# pred_cluster
# 0    75.471698
# 1    18.867925
# 2     3.773585
# 3     1.886792
# Name: proportion, dtype: float64
#     Target player Alec Burks cluster percentages:
# pred_cluster
# 0    75.471698
# 1    18.867925
# 2     3.773585
# 3     1.886792
# Name: proportion, dtype: float64
#     The traded player Alec Burks is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Dennis Schröder (G)...
#   Processing data for Tyus Jones...
#     Cluster percentages for Tyus Jones:
# pred_cluster
# 0    60.919540
# 3    29.885057
# 2     5.747126
# 1     3.448276
# Name: proportion, dtype: float64
#   Processing data for Lonnie Walker IV...
#     Cluster percentages for Lonnie Walker IV:
# pred_cluster
# 0    77.586207
# 2    10.344828
# 1     8.620690
# 3     3.448276
# Name: proportion, dtype: float64
#   Processing data for Cole Anthony...
#     Cluster percentages for Cole Anthony:
# pred_cluster
# 0    59.210526
# 1    30.263158
# 3    10.526316
# Name: proportion, dtype: float64
#   Processing data for Dennis Schröder...
#     Cluster percentages for Dennis Schröder:
# pred_cluster
# 3    57.731959
# 0    28.865979
# 1    11.340206
# 2     2.061856
# Name: proportion, dtype: float64
#     Target player Dennis Schröder cluster percentages:
# pred_cluster
# 3    57.731959
# 0    28.865979
# 1    11.340206
# 2     2.061856
# Name: proportion, dtype: float64
#     The traded player Dennis Schröder is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Spencer Dinwiddie (G)...
#   Processing data for Immanuel Quickley...
#     Cluster percentages for Immanuel Quickley:
# pred_cluster
# 0    54.761905
# 1    22.619048
# 3    21.428571
# 2     1.190476
# Name: proportion, dtype: float64
#   Processing data for Kyle Lowry...
#     Cluster percentages for Kyle Lowry:
# pred_cluster
# 0    62.025316
# 3    22.784810
# 1    11.392405
# 2     3.797468
# Name: proportion, dtype: float64
#   Processing data for Tyus Jones...
#     Cluster percentages for Tyus Jones:
# pred_cluster
# 0    60.919540
# 3    29.885057
# 2     5.747126
# 1     3.448276
# Name: proportion, dtype: float64
#   Processing data for Malik Monk...
#     Cluster percentages for Malik Monk:
# pred_cluster
# 0    69.411765
# 3    21.176471
# 1     9.411765
# Name: proportion, dtype: float64
#   Processing data for Jonas Valančiūnas...
#     Cluster percentages for Jonas Valančiūnas:
# pred_cluster
# 1    70.370370
# 0    25.925926
# 2     2.469136
# 3     1.234568
# Name: proportion, dtype: float64
#   Processing data for Spencer Dinwiddie...
#     Cluster percentages for Spencer Dinwiddie:
# pred_cluster
# 3    74.390244
# 0    20.731707
# 1     4.878049
# Name: proportion, dtype: float64
#     Target player Spencer Dinwiddie cluster percentages:
# pred_cluster
# 3    74.390244
# 0    20.731707
# 1     4.878049
# Name: proportion, dtype: float64
#     The traded player Spencer Dinwiddie is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Patrick Beverley (G)...
#   Processing data for Delon Wright...
#     Cluster percentages for Delon Wright:
# pred_cluster
# 0    73.684211
# 1    14.035088
# 3     8.771930
# 2     3.508772
# Name: proportion, dtype: float64
#   Processing data for De'Anthony Melton...
#     Cluster percentages for De'Anthony Melton:
# pred_cluster
# 0    43.333333
# 1    37.777778
# 3    14.444444
# 2     4.444444
# Name: proportion, dtype: float64
#   Processing data for Jordan McLaughlin...
#     Cluster percentages for Jordan McLaughlin:
# pred_cluster
# 0    68.181818
# 2    31.818182
# Name: proportion, dtype: float64
#   Processing data for Aaron Holiday...
#     Cluster percentages for Aaron Holiday:
# pred_cluster
# 0    69.230769
# 2    24.615385
# 1     4.615385
# 3     1.538462
# Name: proportion, dtype: float64
#   Processing data for Patrick Beverley...
#     Cluster percentages for Patrick Beverley:
# pred_cluster
# 0    72.000000
# 1    16.000000
# 2     6.666667
# 3     5.333333
# Name: proportion, dtype: float64
#     Target player Patrick Beverley cluster percentages:
# pred_cluster
# 0    72.000000
# 1    16.000000
# 2     6.666667
# 3     5.333333
# Name: proportion, dtype: float64
#     The traded player Patrick Beverley is in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Ochai Agbaji (G)...
#   Processing data for Zach LaVine...
#     Cluster percentages for Zach LaVine:
# pred_cluster
# 3    66.176471
# 1    26.470588
# 0     7.352941
# Name: proportion, dtype: float64
#   Processing data for Tyler Herro...
#     Cluster percentages for Tyler Herro:
# pred_cluster
# 1    46.551724
# 3    44.827586
# 0     8.620690
# Name: proportion, dtype: float64
#   Processing data for Jalen Johnson...
#     Cluster percentages for Jalen Johnson:
# pred_cluster
# 0    65.151515
# 1    27.272727
# 2     7.575758
# Name: proportion, dtype: float64
#   Processing data for Jordan Poole...
#     Cluster percentages for Jordan Poole:
# pred_cluster
# 3    63.440860
# 0    24.731183
# 1    10.752688
# 2     1.075269
# Name: proportion, dtype: float64
#   Processing data for Ochai Agbaji...
#     Cluster percentages for Ochai Agbaji:
# pred_cluster
# 0    48.148148
# 1    30.864198
# 3    13.580247
# 2     7.407407
# Name: proportion, dtype: float64
#     Target player Ochai Agbaji cluster percentages:
# pred_cluster
# 0    48.148148
# 1    30.864198
# 3    13.580247
# 2     7.407407
# Name: proportion, dtype: float64
#     The traded player Ochai Agbaji is NOT in the top 3 candidates for the expected cluster (3).
#
# Processing trade for Daniel Gafford (C)...
#   Processing data for Kyle Kuzma...
#     Cluster percentages for Kyle Kuzma:
# pred_cluster
# 1    51.612903
# 3    41.935484
# 0     6.451613
# Name: proportion, dtype: float64
#   Processing data for Daniel Gafford...
#     Cluster percentages for Daniel Gafford:
# pred_cluster
# 1    62.162162
# 0    37.837838
# Name: proportion, dtype: float64
#   Processing data for Jonas Valančiūnas...
#     Cluster percentages for Jonas Valančiūnas:
# pred_cluster
# 1    70.370370
# 0    25.925926
# 2     2.469136
# 3     1.234568
# Name: proportion, dtype: float64
#     Target player Daniel Gafford cluster percentages:
# pred_cluster
# 1    62.162162
# 0    37.837838
# Name: proportion, dtype: float64
#     The traded player Daniel Gafford is in the top 3 candidates for the expected cluster (1).
#
# Overall accuracy for trades in 2024: 70.59%
